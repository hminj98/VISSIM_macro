# %%
"""파일명 변경 코드 """
import os

# 시작 번호 값
start_num = 37

folder_path = r"C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_time_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\1_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\37_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\2_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\38_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\3_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\39_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\4_vehicle_output.xlsx
# ...

# %%
import os

# 시작 번호 값
start_num = 100

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("len(excel_files) : ", len(excel_files))
for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_time_outputs.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# len(excel_files) :  36
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\1_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\100_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\2_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\101_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\3_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\102_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\4_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\103_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\5_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\104_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\6_time_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\105_time_outputs.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\7_time_output.xlsx
# ...

# %%
import os

# 시작 번호 값
start_num = 1

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(3차로)_250417\시뮬레이션 분석 자료_V2.6\중차량,종단경사,교통량\시간별\600"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("excel_files : ",excel_files)

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_weights_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# excel_files :  ['13_weights_output.xlsx', '14_weights_output.xlsx', '15_weights_output.xlsx', '16_weights_output.xlsx', '17_weights_output.xlsx', '18_weights_output.xlsx', '19_weights_output.xlsx', '20_weights_output.xlsx', '21_weights_output.xlsx', '22_weights_output.xlsx', '23_weights_output.xlsx', '24_weights_output.xlsx', '25_weights_output.xlsx', '26_weights_output.xlsx', '27_weights_output.xlsx', '28_weights_output.xlsx', '29_weights_output.xlsx', '30_weights_output.xlsx', '31_weights_output.xlsx', '32_weights_output.xlsx', '33_weights_output.xlsx', '34_weights_output.xlsx', '35_weights_output.xlsx', '36_weights_output.xlsx']
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\가중평균\1350\13_weights_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\가중평균\1350\1_weights_output.xlsx
# ...

# %%
import os

# 시작 번호 값
start_num = 49

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(3차로_실선)_250417\시뮬레이션 분석 자료_V2.6\중차량,종단경사,교통량\차종별\1750"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("excel_files : ",excel_files)

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_vehicle_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# excel_files :  ['49_vehicle_outputs.xlsx', '50_vehicle_outputs.xlsx', '51_vehicle_outputs.xlsx', '52_vehicle_outputs.xlsx', '53_vehicle_outputs.xlsx', '54_vehicle_outputs.xlsx', '55_vehicle_outputs.xlsx', '56_vehicle_outputs.xlsx', '57_vehicle_outputs.xlsx', '58_vehicle_outputs.xlsx', '59_vehicle_outputs.xlsx', '60_vehicle_outputs.xlsx', '61_vehicle_outputs.xlsx', '62_vehicle_outputs.xlsx', '63_vehicle_outputs.xlsx', '64_vehicle_outputs.xlsx', '65_vehicle_outputs.xlsx', '66_vehicle_outputs.xlsx', '67_vehicle_outputs.xlsx', '68_vehicle_outputs.xlsx', '69_vehicle_outputs.xlsx', '70_vehicle_outputs.xlsx', '71_vehicle_outputs.xlsx', '72_vehicle_outputs.xlsx']
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(3차로_실선)_250417\시뮬레이션 분석 자료_V2.6\중차량,종단경사,교통량\차종별\1750\49_vehicle_outputs.xlsx
# ...
