# %%
"""파일명 변경 코드 """
import os

# 시작 번호 값
start_num = 37

folder_path = r"C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_time_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\1_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\37_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\2_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\38_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\3_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\39_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\4_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\40_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\5_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\41_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\6_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\42_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\7_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\43_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\8_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\44_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\9_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\45_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\10_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\46_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\11_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\47_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\12_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\48_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\13_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\49_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\14_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\50_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\15_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\51_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\16_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\52_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\17_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\53_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\18_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\54_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\19_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\55_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\20_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\56_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\21_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\57_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\22_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\58_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\23_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\59_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\24_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\60_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\25_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\61_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\26_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\62_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\27_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\63_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\28_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\64_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\29_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\65_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\30_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\66_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\31_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\67_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\32_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\68_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\33_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\69_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\34_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\70_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\35_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\71_time_output.xlsx
# 기존경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\36_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.1\network01_mer\vehicle_output\72_time_output.xlsx

# %%
import os

# 시작 번호 값
start_num = 13

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("len(excel_files) : ", len(excel_files))
for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_weights_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# len(excel_files) :  12
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\13_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\13_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\14_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\14_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\15_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\15_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\16_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\16_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\17_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\17_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\18_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\18_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\19_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\19_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\20_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\20_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\21_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\21_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\22_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\22_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\23_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\23_weights_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\24_weightst_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\24_weights_output.xlsx

# %%
import os

# 시작 번호 값
start_num = 1

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("excel_files : ",excel_files)

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_vehicle_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# excel_files :  ['1_vehicle_output.xlsx', '2_vehicle_output.xlsx', '3_vehicle_output.xlsx', '4_vehicle_output.xlsx', '5_vehicle_output.xlsx', '6_vehicle_output.xlsx', '7_vehicle_output.xlsx', '8_vehicle_output.xlsx', '9_vehicle_output.xlsx', '10_vehicle_output.xlsx', '11_vehicle_output.xlsx', '12_vehicle_output.xlsx', '13_vehicle_output.xlsx', '14_vehicle_output.xlsx', '15_vehicle_output.xlsx', '16_vehicle_output.xlsx', '17_vehicle_output.xlsx', '18_vehicle_output.xlsx', '19_vehicle_output.xlsx', '20_vehicle_output.xlsx', '21_vehicle_output.xlsx', '22_vehicle_output.xlsx', '23_vehicle_output.xlsx', '24_vehicle_output.xlsx']
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\1_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\1_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\2_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\2_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\3_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\3_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\4_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\4_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\5_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\5_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\6_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\6_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\7_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\7_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\8_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\8_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\9_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\9_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\10_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\10_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\11_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\11_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\12_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\12_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\13_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\13_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\14_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\14_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\15_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\15_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\16_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\16_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\17_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\17_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\18_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\18_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\19_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\19_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\20_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\20_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\21_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\21_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\22_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\22_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\23_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\23_vehicle_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\24_vehicle_output.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\차종별\600\24_vehicle_output.xlsx

# %%
import os

# 시작 번호 값
start_num = 1

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더"
excel_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("excel_files : ",excel_files)

for i in range(len(excel_files)):
    old_path = os.path.join(folder_path, excel_files[i])
    print("기존경로 : ",old_path)
    new_file_name = str(start_num+i)+"_output.xlsx"
    new_path = os.path.join(folder_path, new_file_name)
    print("새로운 파일 경로 : ", new_path)
    os.replace(old_path, new_path)
# Out:
# excel_files :  ['1_output_groupkey_sorted.xlsx', '2_output_groupkey_sorted.xlsx', '3_output_groupkey_sorted.xlsx', '4_output_groupkey_sorted.xlsx', '5_output_groupkey_sorted.xlsx', '6_output_groupkey_sorted.xlsx', '7_output_groupkey_sorted.xlsx', '8_output_groupkey_sorted.xlsx', '9_output_groupkey_sorted.xlsx', '10_output_groupkey_sorted.xlsx', '11_output_groupkey_sorted.xlsx', '12_output_groupkey_sorted.xlsx', '13_output_groupkey_sorted.xlsx', '14_output_groupkey_sorted.xlsx', '15_output_groupkey_sorted.xlsx', '16_output_groupkey_sorted.xlsx', '17_output_groupkey_sorted.xlsx', '18_output_groupkey_sorted.xlsx', '19_output_groupkey_sorted.xlsx', '20_output_groupkey_sorted.xlsx', '21_output_groupkey_sorted.xlsx', '22_output_groupkey_sorted.xlsx', '23_output_groupkey_sorted.xlsx', '24_output_groupkey_sorted.xlsx']
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\1_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\1_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\2_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\2_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\3_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\3_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\4_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\4_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\5_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\5_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\6_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\6_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\7_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\7_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\8_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\8_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\9_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\9_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\10_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\10_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\11_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\11_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\12_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\12_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\13_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\13_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\14_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\14_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\15_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\15_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\16_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\16_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\17_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\17_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\18_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\18_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\19_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\19_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\20_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\20_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\21_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\21_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\22_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\22_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\23_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\23_output.xlsx
# 기존경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\24_output_groupkey_sorted.xlsx
# 새로운 파일 경로 :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\새 폴더\24_output.xlsx
