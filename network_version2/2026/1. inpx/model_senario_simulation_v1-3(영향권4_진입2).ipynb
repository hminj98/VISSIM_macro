# %%
from datetime import datetime
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입"
network_file_name = r"화성~서울(140-유고지점)_260526.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615.inpx")

csv_path = r"C:\Users\alswl\Desktop\유고 시나리오\추정용 시나리오"
csv_file_name = r"synthetic_scenarios_all_140_with_set_type(영향권4(진입))_3차로폐쇄-민진.csv"

# 유고 발생 시각
acc_start_time = 3600
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["q1_ramp_out_vph_per_ratio"]
    Q2_ramp_out_vehph = row["q2_ramp_out_vph_per_ratio"]
    Q3_ramp_out_vehph = row["q3_ramp_out_vph_per_ratio"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    # 종단경사
    #grade_percent = row["grade_percent"] * 0.01

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    # 유고 차로수
    lane_closure_count = int(row["lane_closure_count"])

    # 랜덤시드
    random_seed = int(row["random_seed"])

    # 유고 발생 지점

    incident_location = row["location_name"]
    locations = [x.strip() for x in incident_location.split(",")] # [본선1, 본선2]
    location = locations[0]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_no = routing_decision.get("no")

        # decision별 Q값 매핑
        if decision_no == "1":
            Q = Q1_ramp_out_vehph
        elif decision_no == "2":
            Q = Q2_ramp_out_vehph
        elif decision_no == "3":
            Q = Q3_ramp_out_vehph
        else:
            continue

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue

        for route in veh_routes.findall("vehicleRouteStatic"):
            route_no = route.get("no")

            if route_no == "1":  # 직진
                route.set("relFlow", f"2 0:{round(1 - Q, 3)}")

            elif route_no == "2":  # 진출
                route.set("relFlow", f"2 0:{round(Q, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name in locations:
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))


    # 랜덤시드 설정
    for rds in root.findall(".//simulation"):
        rds.set("randSeed", str(random_seed))


    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}, seed={random_seed}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))

    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 중..."
    )
    Vissim.Simulation.RunContinuous()
    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 완료"
    )

    # 파일 저장 완료 대기
    time.sleep(0.5)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# [2026-06-17 18:16:45] 입력값 | main=3782, ramp=117, seed=118960
# [2026-06-17 18:16:46] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 18:30:00] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_205.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_205.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_205.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_206.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_206.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_206.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_207.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_207.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_207.mer
# [2026-06-17 18:31:42] 입력값 | main=3027, ramp=242, seed=738238
# [2026-06-17 18:31:44] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 18:54:04] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_208.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_208.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_208.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_209.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_209.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_209.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_210.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_210.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_210.mer
# [2026-06-17 18:55:08] 입력값 | main=3457, ramp=142, seed=142322
# [2026-06-17 18:55:09] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 19:08:06] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_211.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_211.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_211.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_212.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_212.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_212.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_213.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_213.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_213.mer
# [2026-06-17 19:10:30] 입력값 | main=3874, ramp=118, seed=700281
# [2026-06-17 19:10:33] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 19:33:49] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_214.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_214.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_214.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_215.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_215.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_215.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_216.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_216.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_216.mer
# [2026-06-17 19:36:55] 입력값 | main=3356, ramp=262, seed=832251
# [2026-06-17 19:36:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 20:08:32] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_217.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_217.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_217.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_218.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_218.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_218.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_219.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_219.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_219.mer
# [2026-06-17 20:10:30] 입력값 | main=3371, ramp=213, seed=378428
# [2026-06-17 20:10:33] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 20:26:35] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_220.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_220.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_220.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_221.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_221.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_221.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_222.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_222.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_222.mer
# [2026-06-17 20:29:22] 입력값 | main=3658, ramp=112, seed=805078
# [2026-06-17 20:29:24] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 20:42:50] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_223.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_223.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_223.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_224.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_224.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_224.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_225.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_225.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_225.mer
# [2026-06-17 20:45:21] 입력값 | main=3133, ramp=180, seed=172656
# [2026-06-17 20:45:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 20:58:27] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_226.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_226.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_226.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_227.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_227.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_227.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_228.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_228.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_228.mer
# [2026-06-17 21:00:30] 입력값 | main=3166, ramp=155, seed=262779
# [2026-06-17 21:00:33] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 21:25:09] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_229.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_229.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_229.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_230.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_230.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_230.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_231.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_231.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_231.mer
# [2026-06-17 21:26:50] 입력값 | main=3202, ramp=232, seed=620557
# [2026-06-17 21:26:52] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 21:38:55] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_232.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_232.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_232.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_233.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_233.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_233.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_234.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_234.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_234.mer
# [2026-06-17 21:41:36] 입력값 | main=3595, ramp=131, seed=85169
# [2026-06-17 21:41:40] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 21:57:45] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_235.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_235.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_235.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_236.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_236.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_236.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_237.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_237.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_237.mer
# [2026-06-17 22:00:31] 입력값 | main=3047, ramp=293, seed=522231
# [2026-06-17 22:00:34] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 22:28:04] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_238.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_238.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_238.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_239.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_239.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_239.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_240.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_240.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_240.mer
# [2026-06-17 22:29:51] 입력값 | main=3911, ramp=282, seed=311883
# [2026-06-17 22:29:53] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 22:46:31] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_241.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_241.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_241.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_242.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_242.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_242.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_243.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_243.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_243.mer
# [2026-06-17 22:49:02] 입력값 | main=3465, ramp=106, seed=636130
# [2026-06-17 22:49:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 23:04:46] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_244.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_244.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_244.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_245.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_245.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_245.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_246.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_246.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_246.mer
# [2026-06-17 23:06:59] 입력값 | main=3148, ramp=153, seed=797616
# [2026-06-17 23:07:01] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 23:32:14] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_247.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_247.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_247.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_248.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_248.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_248.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_249.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_249.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_249.mer
# [2026-06-17 23:34:22] 입력값 | main=3100, ramp=90, seed=979110
# [2026-06-17 23:34:24] VISSIM 시뮬레이션 실행 중...
# [2026-06-17 23:46:49] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_250.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_250.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_250.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_251.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_251.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_251.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_252.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_252.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_252.mer
# [2026-06-17 23:48:07] 입력값 | main=3592, ramp=284, seed=921778
# [2026-06-17 23:48:09] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 00:12:18] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_253.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_253.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_253.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_254.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_254.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_254.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_255.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_255.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_255.mer
# [2026-06-18 00:13:44] 입력값 | main=3316, ramp=207, seed=611681
# [2026-06-18 00:13:46] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 00:25:23] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_256.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_256.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_256.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_257.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_257.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_257.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_258.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_258.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_258.mer
# [2026-06-18 00:27:24] 입력값 | main=3362, ramp=96, seed=299629
# [2026-06-18 00:27:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 00:41:36] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_259.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_259.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_259.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_260.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_260.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_260.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_261.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_261.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_261.mer
# [2026-06-18 00:43:23] 입력값 | main=3550, ramp=91, seed=383714
# [2026-06-18 00:43:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 01:08:21] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_262.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_262.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_262.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_263.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_263.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_263.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_264.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_264.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_264.mer
# [2026-06-18 01:09:48] 입력값 | main=3047, ramp=168, seed=528751
# [2026-06-18 01:09:49] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 01:20:41] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_265.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_265.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_265.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_266.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_266.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_266.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_267.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_267.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_267.mer
# [2026-06-18 01:22:25] 입력값 | main=3462, ramp=286, seed=101378
# [2026-06-18 01:22:26] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 01:37:03] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_268.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_268.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_268.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_269.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_269.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_269.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_270.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_270.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_270.mer
# [2026-06-18 01:39:03] 입력값 | main=3404, ramp=181, seed=631729
# [2026-06-18 01:39:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 02:04:08] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_271.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_271.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_271.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_272.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_272.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_272.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_273.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_273.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_273.mer
# [2026-06-18 02:05:39] 입력값 | main=3621, ramp=333, seed=622566
# [2026-06-18 02:05:40] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 02:24:29] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_274.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_274.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_274.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_275.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_275.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_275.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_276.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_276.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_276.mer
# [2026-06-18 02:26:23] 입력값 | main=3345, ramp=211, seed=386252
# [2026-06-18 02:26:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 02:50:22] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_277.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_277.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_277.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_278.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_278.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_278.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_279.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_279.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_279.mer
# [2026-06-18 02:51:45] 입력값 | main=3645, ramp=288, seed=600384
# [2026-06-18 02:51:48] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 03:19:13] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_280.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_280.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_280.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_281.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_281.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_281.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_282.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_282.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_282.mer
# [2026-06-18 03:20:40] 입력값 | main=3718, ramp=123, seed=430312
# [2026-06-18 03:20:42] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 03:35:08] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_283.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_283.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_283.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_284.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_284.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_284.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_285.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_285.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_285.mer
# [2026-06-18 03:37:23] 입력값 | main=3801, ramp=407, seed=97252
# [2026-06-18 03:37:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 04:11:58] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_286.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_286.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_286.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_287.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_287.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_287.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_288.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_288.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_288.mer
# [2026-06-18 04:13:18] 입력값 | main=3824, ramp=295, seed=82628
# [2026-06-18 04:13:20] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 04:43:50] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_289.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_289.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_289.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_290.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_290.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_290.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_291.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_291.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_291.mer
# [2026-06-18 04:45:03] 입력값 | main=3960, ramp=382, seed=83668
# [2026-06-18 04:45:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 05:16:21] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_292.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_292.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_292.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_293.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_293.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_293.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_294.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_294.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_294.mer
# [2026-06-18 05:17:33] 입력값 | main=3825, ramp=301, seed=735912
# [2026-06-18 05:17:34] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 05:47:25] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_295.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_295.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_295.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_296.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_296.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_296.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_297.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_297.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_297.mer
# [2026-06-18 05:48:42] 입력값 | main=3955, ramp=386, seed=883795
# [2026-06-18 05:48:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 06:18:51] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_298.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_298.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_298.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_299.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_299.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_299.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_300.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_300.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_300.mer
# [2026-06-18 06:20:14] 입력값 | main=3858, ramp=430, seed=687278
# [2026-06-18 06:20:16] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 06:53:04] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_301.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_301.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_301.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_302.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_302.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_302.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_303.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_303.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_303.mer
# [2026-06-18 06:54:20] 입력값 | main=3670, ramp=186, seed=625381
# [2026-06-18 06:54:22] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 07:22:46] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_304.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_304.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_304.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_305.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_305.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_305.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_306.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_306.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_306.mer
# [2026-06-18 07:24:25] 입력값 | main=3797, ramp=167, seed=805935
# [2026-06-18 07:24:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 07:50:56] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_307.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_307.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_307.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_308.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_308.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_308.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_309.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_309.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_309.mer
# [2026-06-18 07:52:36] 입력값 | main=3657, ramp=145, seed=912805
# [2026-06-18 07:52:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 08:18:31] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_310.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_310.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_310.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_311.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_311.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_311.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_312.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_312.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_312.mer
# [2026-06-18 08:20:08] 입력값 | main=3859, ramp=214, seed=20423
# [2026-06-18 08:20:10] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 08:49:25] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_313.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_313.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_313.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_314.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_314.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_314.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_315.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_315.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_315.mer
# [2026-06-18 08:51:08] 입력값 | main=3785, ramp=261, seed=767461
# [2026-06-18 08:51:10] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 09:14:57] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_316.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_316.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_316.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_317.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_317.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_317.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_318.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_318.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_318.mer
# [2026-06-18 09:16:37] 입력값 | main=3435, ramp=254, seed=553307
# [2026-06-18 09:16:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 09:36:41] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_319.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_319.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_319.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_320.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_320.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_320.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_321.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_321.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_321.mer
# [2026-06-18 09:38:35] 입력값 | main=3461, ramp=130, seed=74442
# [2026-06-18 09:38:37] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 09:57:25] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_322.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_322.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_322.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_323.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_323.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_323.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_324.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_324.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_324.mer
# [2026-06-18 09:59:24] 입력값 | main=3908, ramp=239, seed=98908
# [2026-06-18 09:59:26] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 10:29:01] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_325.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_325.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_325.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_326.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_326.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_326.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_327.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_327.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_327.mer
# [2026-06-18 10:30:29] 입력값 | main=3906, ramp=227, seed=422180
# [2026-06-18 10:30:31] VISSIM 시뮬레이션 실행 중...
# [2026-06-18 11:01:23] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_328.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_328.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_328.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_329.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_329.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_329.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_330.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_330.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(110-영향권4_진입_3차로폐쇄-추정용)_260615_330.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
