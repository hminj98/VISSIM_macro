# %%
from datetime import datetime
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입"
network_file_name = r"화성~서울(140-유고지점)_260526.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(140-영향권4_진입_3차로폐쇄)_260610.inpx")

csv_path = r"C:\Users\alswl\Desktop\유고 시나리오\추정용 시나리오"
csv_file_name = r"synthetic_scenarios_all_140_with_set_type(영향권4(진입))_3차로폐쇄.csv"

# 유고 발생 시각
acc_start_time = 3600
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["q1_ramp_out_vph_per_ratio"]
    Q2_ramp_out_vehph = row["q2_ramp_out_vph_per_ratio"]
    Q3_ramp_out_vehph = row["q3_ramp_out_vph_per_ratio"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    # 종단경사
    #grade_percent = row["grade_percent"] * 0.01

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    # 유고 차로수
    lane_closure_count = int(row["lane_closure_count"])

    # 랜덤시드
    random_seed = int(row["random_seed"])

    # 유고 발생 지점

    incident_location = row["location_name"]
    locations = [x.strip() for x in incident_location.split(",")] # [본선1, 본선2]
    location = locations[0]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_no = routing_decision.get("no")

        # decision별 Q값 매핑
        if decision_no == "1":
            Q = Q1_ramp_out_vehph
        elif decision_no == "2":
            Q = Q2_ramp_out_vehph
        elif decision_no == "3":
            Q = Q3_ramp_out_vehph
        else:
            continue

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue

        for route in veh_routes.findall("vehicleRouteStatic"):
            route_no = route.get("no")

            if route_no == "1":  # 직진
                route.set("relFlow", f"2 0:{round(1 - Q, 3)}")

            elif route_no == "2":  # 진출
                route.set("relFlow", f"2 0:{round(Q, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name in locations:
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))


    # 랜덤시드 설정
    for rds in root.findall(".//simulation"):
        rds.set("randSeed", str(random_seed))


    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}, seed={random_seed}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))

    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 중..."
    )
    Vissim.Simulation.RunContinuous()
    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 완료"
    )

    # 파일 저장 완료 대기
    time.sleep(2)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# [2026-06-12 18:28:41] 입력값 | main=1444, ramp=106, seed=710527
# [2026-06-12 18:28:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 18:33:58] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_001.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_001.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_001.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_002.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_002.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_002.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_003.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_003.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_003.mer
# [2026-06-12 18:34:45] 입력값 | main=1619, ramp=60, seed=479028
# [2026-06-12 18:34:46] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 18:39:47] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_004.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_004.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_004.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_005.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_005.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_005.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_006.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_006.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_006.mer
# [2026-06-12 18:40:34] 입력값 | main=1118, ramp=45, seed=733248
# [2026-06-12 18:40:35] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 18:47:01] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_007.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_007.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_007.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_008.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_008.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_008.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_009.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_009.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_009.mer
# [2026-06-12 18:47:34] 입력값 | main=1741, ramp=141, seed=229643
# [2026-06-12 18:47:35] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 18:53:33] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_010.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_010.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_010.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_011.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_011.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_011.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_012.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_012.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_012.mer
# [2026-06-12 18:54:22] 입력값 | main=1785, ramp=131, seed=953814
# [2026-06-12 18:54:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:02:01] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_013.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_013.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_013.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_014.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_014.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_014.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_015.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_015.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_015.mer
# [2026-06-12 19:02:56] 입력값 | main=1104, ramp=55, seed=870814
# [2026-06-12 19:02:57] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:06:47] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_016.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_016.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_016.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_017.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_017.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_017.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_018.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_018.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_018.mer
# [2026-06-12 19:07:20] 입력값 | main=836, ramp=37, seed=491082
# [2026-06-12 19:07:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:11:51] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_019.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_019.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_019.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_020.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_020.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_020.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_021.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_021.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_021.mer
# [2026-06-12 19:12:16] 입력값 | main=1308, ramp=34, seed=612956
# [2026-06-12 19:12:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:16:16] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_022.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_022.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_022.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_023.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_023.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_023.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_024.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_024.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_024.mer
# [2026-06-12 19:16:55] 입력값 | main=1749, ramp=73, seed=122344
# [2026-06-12 19:16:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:23:04] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_025.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_025.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_025.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_026.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_026.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_026.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_027.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_027.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_027.mer
# [2026-06-12 19:23:57] 입력값 | main=1408, ramp=83, seed=63492
# [2026-06-12 19:23:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:28:19] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_028.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_028.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_028.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_029.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_029.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_029.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_030.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_030.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_030.mer
# [2026-06-12 19:29:04] 입력값 | main=1315, ramp=60, seed=672876
# [2026-06-12 19:29:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:35:45] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_031.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_031.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_031.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_032.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_032.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_032.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_033.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_033.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_033.mer
# [2026-06-12 19:36:26] 입력값 | main=1722, ramp=169, seed=870128
# [2026-06-12 19:36:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:43:41] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_034.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_034.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_034.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_035.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_035.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_035.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_036.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_036.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_036.mer
# [2026-06-12 19:44:37] 입력값 | main=796, ramp=79, seed=15583
# [2026-06-12 19:44:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:49:09] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_037.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_037.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_037.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_038.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_038.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_038.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_039.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_039.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_039.mer
# [2026-06-12 19:49:35] 입력값 | main=1233, ramp=104, seed=777748
# [2026-06-12 19:49:36] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:53:24] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_040.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_040.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_040.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_041.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_041.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_041.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_042.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_042.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_042.mer
# [2026-06-12 19:54:07] 입력값 | main=1362, ramp=88, seed=473963
# [2026-06-12 19:54:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 19:58:20] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_043.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_043.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_043.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_044.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_044.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_044.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_045.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_045.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_045.mer
# [2026-06-12 19:59:04] 입력값 | main=1531, ramp=64, seed=480293
# [2026-06-12 19:59:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:08:14] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_046.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_046.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_046.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_047.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_047.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_047.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_048.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_048.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_048.mer
# [2026-06-12 20:09:01] 입력값 | main=563, ramp=17, seed=77061
# [2026-06-12 20:09:02] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:11:21] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_049.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_049.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_049.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_050.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_050.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_050.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_051.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_051.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_051.mer
# [2026-06-12 20:11:40] 입력값 | main=1586, ramp=75, seed=450962
# [2026-06-12 20:11:41] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:20:12] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_052.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_052.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_052.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_053.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_053.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_053.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_054.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_054.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_054.mer
# [2026-06-12 20:21:04] 입력값 | main=1424, ramp=131, seed=327731
# [2026-06-12 20:21:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:25:58] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_055.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_055.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_055.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_056.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_056.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_056.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_057.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_057.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_057.mer
# [2026-06-12 20:26:43] 입력값 | main=1374, ramp=67, seed=95657
# [2026-06-12 20:26:44] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:31:10] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_058.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_058.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_058.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_059.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_059.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_059.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_060.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_060.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_060.mer
# [2026-06-12 20:31:53] 입력값 | main=674, ramp=22, seed=614954
# [2026-06-12 20:31:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:35:44] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_061.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_061.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_061.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_062.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_062.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_062.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_063.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_063.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_063.mer
# [2026-06-12 20:36:05] 입력값 | main=1650, ramp=111, seed=301602
# [2026-06-12 20:36:06] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:40:50] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_064.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_064.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_064.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_065.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_065.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_065.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_066.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_066.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_066.mer
# [2026-06-12 20:41:42] 입력값 | main=1729, ramp=84, seed=888433
# [2026-06-12 20:41:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:47:15] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_067.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_067.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_067.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_068.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_068.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_068.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_069.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_069.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_069.mer
# [2026-06-12 20:48:06] 입력값 | main=721, ramp=37, seed=886210
# [2026-06-12 20:48:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:52:28] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_070.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_070.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_070.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_071.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_071.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_071.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_072.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_072.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_072.mer
# [2026-06-12 20:52:50] 입력값 | main=1648, ramp=162, seed=30360
# [2026-06-12 20:52:51] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 20:58:05] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_073.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_073.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_073.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_074.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_074.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_074.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_075.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_075.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_075.mer
# [2026-06-12 20:58:52] 입력값 | main=869, ramp=40, seed=593831
# [2026-06-12 20:58:53] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:01:53] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_076.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_076.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_076.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_077.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_077.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_077.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_078.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_078.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_078.mer
# [2026-06-12 21:02:18] 입력값 | main=1320, ramp=40, seed=394469
# [2026-06-12 21:02:19] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:08:42] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_079.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_079.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_079.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_080.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_080.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_080.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_081.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_081.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_081.mer
# [2026-06-12 21:09:22] 입력값 | main=1359, ramp=80, seed=163138
# [2026-06-12 21:09:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:13:24] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_082.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_082.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_082.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_083.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_083.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_083.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_084.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_084.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_084.mer
# [2026-06-12 21:14:07] 입력값 | main=822, ramp=67, seed=636566
# [2026-06-12 21:14:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:17:22] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_085.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_085.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_085.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_086.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_086.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_086.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_087.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_087.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_087.mer
# [2026-06-12 21:17:49] 입력값 | main=1405, ramp=79, seed=711164
# [2026-06-12 21:17:50] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:26:40] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_088.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_088.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_088.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_089.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_089.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_089.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_090.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_090.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_090.mer
# [2026-06-12 21:27:27] 입력값 | main=1714, ramp=106, seed=8061
# [2026-06-12 21:27:28] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:33:24] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_091.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_091.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_091.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_092.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_092.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_092.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_093.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_093.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_093.mer
# [2026-06-12 21:34:17] 입력값 | main=2819, ramp=229, seed=416360
# [2026-06-12 21:34:18] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 21:49:31] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_094.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_094.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_094.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_095.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_095.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_095.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_096.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_096.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_096.mer
# [2026-06-12 21:50:35] 입력값 | main=1887, ramp=109, seed=743964
# [2026-06-12 21:50:36] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 22:04:02] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_097.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_097.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_097.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_098.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_098.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_098.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_099.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_099.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_099.mer
# [2026-06-12 22:04:57] 입력값 | main=2656, ramp=124, seed=872443
# [2026-06-12 22:04:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 22:19:06] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_100.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_100.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_100.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_101.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_101.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_101.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_102.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_102.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_102.mer
# [2026-06-12 22:20:06] 입력값 | main=2542, ramp=80, seed=414992
# [2026-06-12 22:20:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 22:32:59] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_103.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_103.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_103.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_104.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_104.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_104.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_105.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_105.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_105.mer
# [2026-06-12 22:33:55] 입력값 | main=2436, ramp=198, seed=556380
# [2026-06-12 22:33:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 22:50:54] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_106.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_106.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_106.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_107.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_107.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_107.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_108.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_108.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_108.mer
# [2026-06-12 22:51:52] 입력값 | main=2100, ramp=93, seed=997503
# [2026-06-12 22:51:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 23:01:42] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_109.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_109.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_109.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_110.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_110.parquet
# ...
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_294.mer
# [2026-06-13 16:36:22] 입력값 | main=3825, ramp=301, seed=735912
# [2026-06-13 16:36:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 16:58:41] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_295.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_295.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_295.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_296.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_296.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_296.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_297.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_297.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_297.mer
# [2026-06-13 16:59:35] 입력값 | main=3955, ramp=386, seed=883795
# [2026-06-13 16:59:36] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 17:21:49] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_298.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_298.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_298.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_299.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_299.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_299.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_300.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_300.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_300.mer
# [2026-06-13 17:22:46] 입력값 | main=3858, ramp=430, seed=687278
# [2026-06-13 17:22:47] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 17:45:00] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_301.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_301.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_301.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_302.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_302.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_302.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_303.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_303.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_303.mer
# [2026-06-13 17:45:59] 입력값 | main=3670, ramp=186, seed=625381
# [2026-06-13 17:46:00] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 18:05:37] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_304.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_304.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_304.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_305.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_305.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_305.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_306.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_306.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_306.mer
# [2026-06-13 18:06:37] 입력값 | main=3797, ramp=167, seed=805935
# [2026-06-13 18:06:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 18:25:14] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_307.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_307.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_307.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_308.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_308.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_308.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_309.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_309.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_309.mer
# [2026-06-13 18:26:14] 입력값 | main=3657, ramp=145, seed=912805
# [2026-06-13 18:26:15] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 18:46:31] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_310.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_310.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_310.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_311.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_311.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_311.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_312.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_312.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_312.mer
# [2026-06-13 18:47:35] 입력값 | main=3859, ramp=214, seed=20423
# [2026-06-13 18:47:36] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 19:07:21] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_313.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_313.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_313.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_314.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_314.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_314.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_315.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_315.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_315.mer
# [2026-06-13 19:08:20] 입력값 | main=3785, ramp=261, seed=767461
# [2026-06-13 19:08:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 19:27:46] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_316.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_316.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_316.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_317.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_317.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_317.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_318.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_318.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_318.mer
# [2026-06-13 19:28:44] 입력값 | main=3435, ramp=254, seed=553307
# [2026-06-13 19:28:45] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 19:44:38] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_319.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_319.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_319.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_320.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_320.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_320.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_321.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_321.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_321.mer
# [2026-06-13 19:45:40] 입력값 | main=3461, ramp=130, seed=74442
# [2026-06-13 19:45:41] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 20:00:40] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_322.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_322.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_322.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_323.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_323.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_323.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_324.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_324.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_324.mer
# [2026-06-13 20:01:46] 입력값 | main=3908, ramp=239, seed=98908
# [2026-06-13 20:01:47] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 20:23:29] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_325.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_325.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_325.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_326.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_326.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_326.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_327.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_327.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_327.mer
# [2026-06-13 20:24:26] 입력값 | main=3906, ramp=227, seed=422180
# [2026-06-13 20:24:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-13 20:47:14] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_328.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_328.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_328.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_329.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_329.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_329.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_330.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_330.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\연결로 영향권_3차로폐쇄\영향권4_진입\화성~서울(140-영향권4_진입_3차로폐쇄)_260610_330.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
