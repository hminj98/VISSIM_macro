# %%
from datetime import datetime
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2"
network_file_name = r"화성~서울(140-유고지점)_260526.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(30-본선부_구간2-검증용)_260615.inpx")

csv_path = r"C:\Users\alswl\Desktop\유고 시나리오\검증용 시나리오"
csv_file_name = r"synthetic_scenarios_all_140_with_set_type(본선부-구간2).csv"

# 유고 발생 시각
acc_start_time = 3600
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["q1_ramp_out_vph_per_ratio"]
    Q2_ramp_out_vehph = row["q2_ramp_out_vph_per_ratio"]
    Q3_ramp_out_vehph = row["q3_ramp_out_vph_per_ratio"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    # 종단경사
    #grade_percent = row["grade_percent"] * 0.01

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    # 유고 차로수
    lane_closure_count = int(row["lane_closure_count"])

    # 랜덤시드
    random_seed = int(row["random_seed"])

    # 유고 발생 지점

    incident_location = row["location_name"]
    locations = [x.strip() for x in incident_location.split(",")] # [본선1, 본선2]
    location = locations[0]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_no = routing_decision.get("no")

        # decision별 Q값 매핑
        if decision_no == "1":
            Q = Q1_ramp_out_vehph
        elif decision_no == "2":
            Q = Q2_ramp_out_vehph
        elif decision_no == "3":
            Q = Q3_ramp_out_vehph
        else:
            continue

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue

        for route in veh_routes.findall("vehicleRouteStatic"):
            route_no = route.get("no")

            if route_no == "1":  # 직진
                route.set("relFlow", f"2 0:{round(1 - Q, 3)}")

            elif route_no == "2":  # 진출
                route.set("relFlow", f"2 0:{round(Q, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name in locations:
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))


    # 랜덤시드 설정
    for rds in root.findall(".//simulation"):
        rds.set("randSeed", str(random_seed))


    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}, seed={random_seed}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))

    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 중..."
    )
    Vissim.Simulation.RunContinuous()
    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 완료"
    )

    # 파일 저장 완료 대기
    time.sleep(2)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# [2026-06-15 16:55:57] 입력값 | main=1104, ramp=30, seed=954852
# [2026-06-15 16:55:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 16:59:58] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_001.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_001.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_001.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_002.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_002.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_002.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_003.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_003.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_003.mer
# [2026-06-15 17:00:28] 입력값 | main=889, ramp=64, seed=947288
# [2026-06-15 17:00:29] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:04:40] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_004.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_004.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_004.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_005.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_005.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_005.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_006.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_006.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_006.mer
# [2026-06-15 17:05:04] 입력값 | main=654, ramp=23, seed=94690
# [2026-06-15 17:05:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:07:43] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_007.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_007.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_007.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_008.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_008.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_008.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_009.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_009.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_009.mer
# [2026-06-15 17:08:00] 입력값 | main=1280, ramp=111, seed=959716
# [2026-06-15 17:08:01] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:14:30] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_010.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_010.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_010.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_011.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_011.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_011.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_012.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_012.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_012.mer
# [2026-06-15 17:15:06] 입력값 | main=786, ramp=23, seed=407525
# [2026-06-15 17:15:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:17:53] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_013.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_013.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_013.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_014.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_014.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_014.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_015.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_015.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_015.mer
# [2026-06-15 17:18:15] 입력값 | main=1429, ramp=76, seed=686736
# [2026-06-15 17:18:16] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:26:03] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_016.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_016.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_016.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_017.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_017.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_017.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_018.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_018.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_018.mer
# [2026-06-15 17:26:42] 입력값 | main=702, ramp=62, seed=227824
# [2026-06-15 17:26:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:29:19] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_019.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_019.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_019.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_020.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_020.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_020.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_021.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_021.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_021.mer
# [2026-06-15 17:29:40] 입력값 | main=1635, ramp=66, seed=290744
# [2026-06-15 17:29:41] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:34:12] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_022.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_022.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_022.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_023.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_023.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_023.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_024.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_024.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_024.mer
# [2026-06-15 17:34:55] 입력값 | main=665, ramp=33, seed=626411
# [2026-06-15 17:34:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:37:32] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_025.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_025.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_025.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_026.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_026.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_026.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_027.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_027.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_027.mer
# [2026-06-15 17:37:50] 입력값 | main=2219, ramp=106, seed=8106
# [2026-06-15 17:37:52] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:43:44] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_028.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_028.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_028.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_029.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_029.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_029.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_030.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_030.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_030.mer
# [2026-06-15 17:44:46] 입력값 | main=2845, ramp=113, seed=107799
# [2026-06-15 17:44:47] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:51:53] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_031.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_031.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_031.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_032.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_032.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_032.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_033.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_033.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_033.mer
# [2026-06-15 17:53:12] 입력값 | main=1952, ramp=95, seed=644884
# [2026-06-15 17:53:13] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 17:58:43] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_034.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_034.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_034.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_035.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_035.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_035.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_036.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_036.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_036.mer
# [2026-06-15 17:59:38] 입력값 | main=2264, ramp=227, seed=918965
# [2026-06-15 17:59:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 18:06:16] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_037.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_037.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_037.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_038.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_038.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_038.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_039.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_039.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_039.mer
# [2026-06-15 18:07:24] 입력값 | main=2642, ramp=139, seed=245370
# [2026-06-15 18:07:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 18:18:39] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_040.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_040.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_040.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_041.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_041.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_041.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_042.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_042.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_042.mer
# [2026-06-15 18:20:11] 입력값 | main=2894, ramp=125, seed=711257
# [2026-06-15 18:20:13] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 18:29:24] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_043.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_043.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_043.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_044.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_044.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_044.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_045.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_045.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_045.mer
# [2026-06-15 18:30:55] 입력값 | main=2255, ramp=195, seed=247232
# [2026-06-15 18:30:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 18:44:07] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_046.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_046.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_046.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_047.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_047.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_047.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_048.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_048.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_048.mer
# [2026-06-15 18:45:22] 입력값 | main=2013, ramp=167, seed=853026
# [2026-06-15 18:45:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 18:57:11] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_049.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_049.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_049.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_050.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_050.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_050.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_051.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_051.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_051.mer
# [2026-06-15 18:58:19] 입력값 | main=2616, ramp=259, seed=374315
# [2026-06-15 18:58:20] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 19:18:20] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_052.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_052.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_052.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_053.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_053.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_053.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_054.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_054.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_054.mer
# [2026-06-15 19:20:02] 입력값 | main=3623, ramp=276, seed=379743
# [2026-06-15 19:20:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 19:41:24] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_055.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_055.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_055.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_056.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_056.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_056.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_057.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_057.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_057.mer
# [2026-06-15 19:43:04] 입력값 | main=3568, ramp=243, seed=324315
# [2026-06-15 19:43:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 20:00:12] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_058.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_058.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_058.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_059.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_059.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_059.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_060.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_060.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_060.mer
# [2026-06-15 20:02:23] 입력값 | main=3408, ramp=341, seed=332428
# [2026-06-15 20:02:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 20:21:34] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_061.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_061.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_061.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_062.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_062.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_062.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_063.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_063.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_063.mer
# [2026-06-15 20:23:29] 입력값 | main=3380, ramp=215, seed=147721
# [2026-06-15 20:23:30] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 20:37:49] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_064.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_064.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_064.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_065.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_065.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_065.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_066.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_066.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_066.mer
# [2026-06-15 20:40:03] 입력값 | main=3522, ramp=194, seed=156176
# [2026-06-15 20:40:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 20:56:40] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_067.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_067.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_067.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_068.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_068.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_068.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_069.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_069.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_069.mer
# [2026-06-15 20:59:01] 입력값 | main=3340, ramp=252, seed=278429
# [2026-06-15 20:59:03] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 21:13:15] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_070.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_070.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_070.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_071.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_071.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_071.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_072.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_072.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_072.mer
# [2026-06-15 21:15:23] 입력값 | main=3672, ramp=307, seed=549698
# [2026-06-15 21:15:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 21:29:29] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_073.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_073.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_073.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_074.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_074.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_074.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_075.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_075.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_075.mer
# [2026-06-15 21:31:13] 입력값 | main=3806, ramp=402, seed=33327
# [2026-06-15 21:31:14] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 21:49:03] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_076.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_076.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_076.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_077.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_077.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_077.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_078.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_078.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_078.mer
# [2026-06-15 21:50:30] 입력값 | main=3823, ramp=254, seed=471030
# [2026-06-15 21:50:31] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 22:06:38] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_079.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_079.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_079.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_080.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_080.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_080.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_081.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_081.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_081.mer
# [2026-06-15 22:08:18] 입력값 | main=3802, ramp=263, seed=379581
# [2026-06-15 22:08:19] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 22:26:59] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_082.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_082.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_082.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_083.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_083.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_083.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_084.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_084.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_084.mer
# [2026-06-15 22:28:23] 입력값 | main=3508, ramp=251, seed=943314
# [2026-06-15 22:28:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 22:42:39] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_085.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_085.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_085.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_086.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_086.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_086.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_087.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_087.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_087.mer
# [2026-06-15 22:44:16] 입력값 | main=3517, ramp=194, seed=565428
# [2026-06-15 22:44:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-15 22:59:06] VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_088.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_088.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_088.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_089.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_089.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_089.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_090.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_090.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간2\화성~서울(30-본선부_구간2-검증용)_260615_090.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
