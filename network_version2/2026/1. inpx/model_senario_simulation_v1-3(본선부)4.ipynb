# %%
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4"
network_file_name = r"화성~서울(140-유고지점)_260518.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(140-본선부_구간4)_260426.inpx")

csv_path = r"C:\Users\alswl\Desktop\26.05.18"
csv_file_name = r"synthetic_scenarios_all_140_with_set_type(본선부-구간4).csv"

# 유고 발생 시각
acc_start_time = 3600
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["q1_ramp_out_vph_per_ratio"]
    Q2_ramp_out_vehph = row["q2_ramp_out_vph_per_ratio"]
    Q3_ramp_out_vehph = row["q3_ramp_out_vph_per_ratio"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    # 종단경사
    #grade_percent = row["grade_percent"] * 0.01

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    # 유고 차로수
    lane_closure_count = int(row["lane_closure_count"])

    # 랜덤시드
    random_seed = int(row["random_seed"])

    # 유고 발생 지점

    incident_location = row["location_name"]
    locations = [x.strip() for x in incident_location.split(",")] # [본선1, 본선2]
    location = locations[0]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_no = routing_decision.get("no")

        # decision별 Q값 매핑
        if decision_no == "1":
            Q = Q1_ramp_out_vehph
        elif decision_no == "2":
            Q = Q2_ramp_out_vehph
        elif decision_no == "3":
            Q = Q3_ramp_out_vehph
        else:
            continue

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue

        for route in veh_routes.findall("vehicleRouteStatic"):
            route_no = route.get("no")

            if route_no == "1":  # 직진
                route.set("relFlow", f"2 0:{round(1 - Q, 3)}")

            elif route_no == "2":  # 진출
                route.set("relFlow", f"2 0:{round(Q, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name in locations:
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))


    # 랜덤시드 설정
    for rds in root.findall(".//simulation"):
        rds.set("randSeed", str(random_seed))


    print(
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}, seed={random_seed}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))

    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print("VISSIM 시뮬레이션 실행 중...")
    Vissim.Simulation.RunContinuous()
    print("VISSIM 시뮬레이션 실행 완료")

    # 파일 저장 완료 대기
    time.sleep(2)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# 입력값 | main=1444, ramp=106, seed=710527
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_001.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_001.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_001.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_002.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_002.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_002.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_003.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_003.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_003.mer
# 입력값 | main=1619, ramp=60, seed=479028
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_004.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_004.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_004.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_005.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_005.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_005.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_006.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_006.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_006.mer
# 입력값 | main=1118, ramp=45, seed=733248
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_007.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_007.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_007.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_008.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_008.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_008.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_009.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_009.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_009.mer
# 입력값 | main=1741, ramp=141, seed=229643
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_010.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_010.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_010.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_011.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_011.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_011.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_012.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_012.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_012.mer
# 입력값 | main=1785, ramp=131, seed=953814
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_013.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_013.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_013.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_014.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_014.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_014.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_015.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_015.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_015.mer
# 입력값 | main=1104, ramp=55, seed=870814
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_016.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_016.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_016.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_017.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_017.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_017.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_018.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_018.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_018.mer
# 입력값 | main=836, ramp=37, seed=491082
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_019.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_019.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_019.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_020.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_020.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_020.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_021.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_021.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_021.mer
# 입력값 | main=1308, ramp=34, seed=612956
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_022.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_022.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_022.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_023.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_023.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_023.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_024.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_024.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_024.mer
# 입력값 | main=1749, ramp=73, seed=122344
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_025.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_025.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_025.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_026.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_026.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_026.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_027.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_027.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_027.mer
# 입력값 | main=1408, ramp=83, seed=63492
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_028.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_028.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_028.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_029.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_029.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_029.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_030.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_030.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_030.mer
# 입력값 | main=1315, ramp=60, seed=672876
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_031.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_031.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_031.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_032.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_032.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_032.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_033.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_033.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_033.mer
# 입력값 | main=1722, ramp=169, seed=870128
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_034.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_034.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_034.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_035.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_035.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_035.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_036.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_036.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_036.mer
# 입력값 | main=796, ramp=79, seed=15583
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_037.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_037.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_037.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_038.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_038.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_038.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_039.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_039.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_039.mer
# 입력값 | main=1233, ramp=104, seed=777748
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_040.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_040.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_040.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_041.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_041.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_041.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_042.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_042.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_042.mer
# 입력값 | main=1362, ramp=88, seed=473963
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_043.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_043.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_043.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_044.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_044.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_044.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_045.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_045.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_045.mer
# 입력값 | main=1531, ramp=64, seed=480293
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_046.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_046.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_046.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_047.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_047.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_047.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_048.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_048.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_048.mer
# 입력값 | main=563, ramp=17, seed=77061
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_049.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_049.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_049.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_050.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_050.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_050.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_051.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_051.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_051.mer
# 입력값 | main=1586, ramp=75, seed=450962
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_052.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_052.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_052.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_053.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_053.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_053.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_054.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_054.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_054.mer
# 입력값 | main=1424, ramp=131, seed=327731
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_055.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_055.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_055.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_056.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_056.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_056.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_057.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_057.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_057.mer
# 입력값 | main=1374, ramp=67, seed=95657
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_058.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_058.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_058.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_059.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_059.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_059.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_060.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_060.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_060.mer
# 입력값 | main=674, ramp=22, seed=614954
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_061.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_061.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_061.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_062.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_062.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_062.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_063.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_063.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_063.mer
# 입력값 | main=1650, ramp=111, seed=301602
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_064.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_064.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_064.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_065.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_065.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_065.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_066.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_066.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_066.mer
# 입력값 | main=1729, ramp=84, seed=888433
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_067.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_067.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_067.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_068.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_068.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_068.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_069.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_069.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_069.mer
# 입력값 | main=721, ramp=37, seed=886210
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_070.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_070.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_070.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_071.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_071.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_071.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_072.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_072.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_072.mer
# 입력값 | main=1648, ramp=162, seed=30360
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_073.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_073.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_073.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_074.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_074.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_074.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_075.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_075.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_075.mer
# 입력값 | main=869, ramp=40, seed=593831
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_076.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_076.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_076.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_077.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_077.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_077.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_078.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_078.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_078.mer
# 입력값 | main=1320, ramp=40, seed=394469
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_079.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_079.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_079.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_080.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_080.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_080.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_081.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_081.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_081.mer
# 입력값 | main=1359, ramp=80, seed=163138
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_082.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_082.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_082.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_083.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_083.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_083.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_084.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_084.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_084.mer
# 입력값 | main=822, ramp=67, seed=636566
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_085.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_085.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_085.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_086.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_086.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_086.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_087.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_087.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_087.mer
# 입력값 | main=1405, ramp=79, seed=711164
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_088.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_088.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_088.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_089.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_089.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_089.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_090.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_090.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_090.mer
# 입력값 | main=1714, ramp=106, seed=8061
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_091.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_091.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_091.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_092.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_092.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_092.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_093.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_093.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_093.mer
# 입력값 | main=2819, ramp=229, seed=416360
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_094.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_094.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_094.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_095.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_095.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_095.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_096.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_096.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_096.mer
# 입력값 | main=1887, ramp=109, seed=743964
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_097.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_097.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_097.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_098.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_098.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_098.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_099.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_099.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_099.mer
# 입력값 | main=2656, ramp=124, seed=872443
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_100.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_100.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_100.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_101.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_101.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_101.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_102.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_102.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_102.mer
# 입력값 | main=2542, ramp=80, seed=414992
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_103.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_103.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_103.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_104.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_104.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_104.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_105.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_105.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_105.mer
# 입력값 | main=2436, ramp=198, seed=556380
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_106.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_106.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_106.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_107.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_107.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_107.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_108.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_108.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_108.mer
# 입력값 | main=2100, ramp=93, seed=997503
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_109.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_109.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_109.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_110.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_110.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_110.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_111.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_111.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_111.mer
# 입력값 | main=2812, ramp=169, seed=158291
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_112.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_112.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_112.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_113.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_113.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_113.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_114.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_114.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_114.mer
# 입력값 | main=2701, ramp=81, seed=531982
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_115.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_115.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_115.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_116.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_116.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_116.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_117.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_117.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_117.mer
# 입력값 | main=2839, ramp=154, seed=953208
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_118.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_118.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_118.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_119.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_119.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_119.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_120.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_120.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_120.mer
# 입력값 | main=2971, ramp=220, seed=108530
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_121.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_121.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_121.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_122.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_122.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_122.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_123.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_123.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_123.mer
# 입력값 | main=2504, ramp=247, seed=549526
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_124.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_124.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_124.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_125.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_125.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_125.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_126.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_126.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_126.mer
# 입력값 | main=2871, ramp=203, seed=827565
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_127.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_127.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_127.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_128.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_128.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_128.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_129.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_129.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_129.mer
# 입력값 | main=2486, ramp=75, seed=349556
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_130.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_130.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_130.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_131.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_131.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_131.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_132.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_132.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_132.mer
# 입력값 | main=1967, ramp=135, seed=135216
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_133.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_133.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_133.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_134.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_134.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_134.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_135.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_135.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_135.mer
# 입력값 | main=1974, ramp=95, seed=677407
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_136.mer
# ...
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_286.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_286.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_286.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_287.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_287.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_287.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_288.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_288.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_288.mer
# 입력값 | main=3824, ramp=295, seed=82628
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_289.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_289.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_289.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_290.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_290.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_290.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_291.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_291.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_291.mer
# 입력값 | main=3960, ramp=382, seed=83668
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_292.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_292.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_292.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_293.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_293.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_293.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_294.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_294.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_294.mer
# 입력값 | main=3825, ramp=301, seed=735912
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_295.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_295.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_295.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_296.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_296.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_296.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_297.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_297.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_297.mer
# 입력값 | main=3955, ramp=386, seed=883795
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_298.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_298.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_298.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_299.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_299.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_299.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_300.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_300.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_300.mer
# 입력값 | main=3858, ramp=430, seed=687278
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_301.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_301.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_301.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_302.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_302.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_302.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_303.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_303.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_303.mer
# 입력값 | main=3670, ramp=186, seed=625381
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_304.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_304.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_304.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_305.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_305.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_305.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_306.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_306.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_306.mer
# 입력값 | main=3797, ramp=167, seed=805935
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_307.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_307.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_307.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_308.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_308.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_308.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_309.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_309.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_309.mer
# 입력값 | main=3657, ramp=145, seed=912805
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_310.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_310.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_310.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_311.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_311.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_311.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_312.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_312.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_312.mer
# 입력값 | main=3859, ramp=214, seed=20423
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_313.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_313.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_313.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_314.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_314.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_314.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_315.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_315.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_315.mer
# 입력값 | main=3785, ramp=261, seed=767461
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_316.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_316.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_316.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_317.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_317.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_317.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_318.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_318.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_318.mer
# 입력값 | main=3435, ramp=254, seed=553307
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_319.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_319.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_319.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_320.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_320.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_320.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_321.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_321.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_321.mer
# 입력값 | main=3461, ramp=130, seed=74442
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_322.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_322.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_322.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_323.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_323.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_323.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_324.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_324.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_324.mer
# 입력값 | main=3908, ramp=239, seed=98908
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_325.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_325.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_325.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_326.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_326.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_326.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_327.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_327.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_327.mer
# 입력값 | main=3906, ramp=227, seed=422180
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_328.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_328.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_328.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_329.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_329.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_329.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_330.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_330.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\본선부\구간4\화성~서울(140-본선부_구간4)_260426_330.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
