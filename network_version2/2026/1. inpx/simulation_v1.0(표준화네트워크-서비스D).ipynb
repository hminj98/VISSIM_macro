# %%
from datetime import datetime
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Users\alswl\Desktop\표준화 네트워크_260519\15km 시나리오\서비스 D"
network_file_name = r"연결로 우회분석_15km_260608.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"연결로 우회분석 결과_서비스 D_15km_260608.inpx")

csv_path = r"C:\Users\alswl\Desktop\표준화 네트워크_260519\15km 시나리오\서비스 D"
csv_file_name = r"서비스 D.csv"

# 유고 발생 시각
acc_start_time = 1800
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["reflow"]

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_name = routing_decision.get("name")
        decision_no = routing_decision.get("no")

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue
        if decision_name == "상류" :
            for route in veh_routes.findall("vehicleRouteStatic"):
                route_no = route.get("no")

                if route_no == "1":  # 직진
                    route.set("relFlow", f"2 0:0.9, 2 1800000:{round(1- Q1_ramp_out_vehph, 3)}")

                elif route_no == "2":  # 진출
                    route.set("relFlow", f"2 0:0.1, 2 1800000:{round(Q1_ramp_out_vehph, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name == "ugo":
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))



    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        f"입력값 | main={Q_main_in_vehph}, 직진비율={1-Q1_ramp_out_vehph}, 진출비율={Q1_ramp_out_vehph}, 유고 지속시간={acc_start_time + incident_duration_min * 60}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)

    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 중..."
    )
    Vissim.Simulation.RunContinuous()
    print(
        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
        "VISSIM 시뮬레이션 실행 완료"
    )

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# [2026-06-11 22:47:57] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=2400
# [2026-06-11 22:47:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 22:50:50] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 22:50:50] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=2400
# [2026-06-11 22:50:52] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 22:53:21] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 22:53:21] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=2400
# [2026-06-11 22:53:22] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 22:55:37] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 22:55:37] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=2400
# [2026-06-11 22:55:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 22:57:40] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 22:57:40] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=2400
# [2026-06-11 22:57:42] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 22:59:29] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 22:59:29] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=2400
# [2026-06-11 22:59:30] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:01:14] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:01:14] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=2400
# [2026-06-11 23:01:15] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:03:25] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:03:25] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=2400
# [2026-06-11 23:03:26] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:06:10] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:06:10] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=2400
# [2026-06-11 23:06:11] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:09:07] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:09:07] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=2400
# [2026-06-11 23:09:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:12:16] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:12:16] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=3000
# [2026-06-11 23:12:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:15:31] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:15:31] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=3000
# [2026-06-11 23:15:32] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:18:18] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:18:18] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=3000
# [2026-06-11 23:18:19] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:20:46] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:20:46] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=3000
# [2026-06-11 23:20:47] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:23:02] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:23:02] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=3000
# [2026-06-11 23:23:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:25:02] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:25:02] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=3000
# [2026-06-11 23:25:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:26:56] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:26:56] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=3000
# [2026-06-11 23:26:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:29:16] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:29:16] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=3000
# [2026-06-11 23:29:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:32:00] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:32:00] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=3000
# [2026-06-11 23:32:01] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:35:15] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:35:15] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=3000
# [2026-06-11 23:35:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:38:22] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:38:22] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=3600
# [2026-06-11 23:38:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:41:35] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:41:35] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=3600
# [2026-06-11 23:41:36] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:44:32] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:44:32] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=3600
# [2026-06-11 23:44:34] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:47:19] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:47:19] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=3600
# [2026-06-11 23:47:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:49:49] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:49:49] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=3600
# [2026-06-11 23:49:50] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:51:49] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:51:49] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=3600
# [2026-06-11 23:51:50] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:53:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:53:38] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=3600
# [2026-06-11 23:53:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:55:53] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:55:53] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=3600
# [2026-06-11 23:55:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-11 23:58:33] VISSIM 시뮬레이션 실행 완료
# [2026-06-11 23:58:33] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=3600
# [2026-06-11 23:58:34] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:01:05] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:01:05] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=3600
# [2026-06-12 00:01:06] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:04:12] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:04:12] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=4200
# [2026-06-12 00:04:13] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:08:06] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:08:06] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=4200
# [2026-06-12 00:08:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:11:20] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:11:20] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=4200
# [2026-06-12 00:11:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:13:48] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:13:48] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=4200
# [2026-06-12 00:13:49] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:15:54] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:15:54] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=4200
# [2026-06-12 00:15:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:17:48] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:17:48] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=4200
# [2026-06-12 00:17:49] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:19:13] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:19:13] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=4200
# [2026-06-12 00:19:14] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:21:16] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:21:16] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=4200
# [2026-06-12 00:21:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:23:39] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:23:39] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=4200
# [2026-06-12 00:23:40] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:26:18] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:26:18] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=4200
# [2026-06-12 00:26:19] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:28:47] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:28:47] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=4800
# [2026-06-12 00:28:48] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:31:45] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:31:45] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=4800
# [2026-06-12 00:31:46] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:34:41] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:34:41] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=4800
# [2026-06-12 00:34:42] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:37:22] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:37:22] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=4800
# [2026-06-12 00:37:22] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:39:20] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:39:20] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=4800
# [2026-06-12 00:39:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:41:12] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:41:12] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=4800
# [2026-06-12 00:41:13] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:42:53] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:42:53] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=4800
# [2026-06-12 00:42:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:44:57] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:44:57] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=4800
# [2026-06-12 00:44:58] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:47:07] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:47:07] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=4800
# [2026-06-12 00:47:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:49:16] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:49:16] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=4800
# [2026-06-12 00:49:17] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:51:40] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:51:40] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=5400
# [2026-06-12 00:51:41] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 00:56:55] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 00:56:55] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=5400
# [2026-06-12 00:56:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:00:13] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:00:13] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=5400
# [2026-06-12 01:00:14] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:02:37] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:02:37] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=5400
# [2026-06-12 01:02:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:04:30] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:04:30] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=5400
# [2026-06-12 01:04:31] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:06:26] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:06:26] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=5400
# [2026-06-12 01:06:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:08:02] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:08:02] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=5400
# [2026-06-12 01:08:03] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:09:58] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:09:58] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=5400
# [2026-06-12 01:09:59] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:12:25] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:12:25] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=5400
# [2026-06-12 01:12:26] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:15:06] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:15:06] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=5400
# [2026-06-12 01:15:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:17:55] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:17:55] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=6000
# [2026-06-12 01:17:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:24:11] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:24:11] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=6000
# [2026-06-12 01:24:12] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:29:03] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:29:03] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=6000
# [2026-06-12 01:29:04] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:31:51] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:31:51] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=6000
# [2026-06-12 01:31:52] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:34:19] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:34:19] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=6000
# [2026-06-12 01:34:20] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:36:20] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:36:20] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=6000
# [2026-06-12 01:36:21] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:38:08] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:38:08] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=6000
# [2026-06-12 01:38:09] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:40:26] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:40:26] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=6000
# [2026-06-12 01:40:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:42:51] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:42:51] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=6000
# [2026-06-12 01:42:52] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:45:33] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:45:33] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=6000
# [2026-06-12 01:45:34] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:48:27] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:48:27] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=6600
# [2026-06-12 01:48:28] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 01:54:54] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 01:54:54] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=6600
# [2026-06-12 01:54:55] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:00:54] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:00:54] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=6600
# [2026-06-12 02:00:55] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:04:53] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:04:53] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=6600
# [2026-06-12 02:04:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:07:39] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:07:39] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=6600
# [2026-06-12 02:07:40] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:09:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:09:38] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=6600
# [2026-06-12 02:09:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:11:11] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:11:11] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=6600
# [2026-06-12 02:11:12] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:13:06] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:13:06] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=6600
# [2026-06-12 02:13:07] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:15:22] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:15:22] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=6600
# [2026-06-12 02:15:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:17:55] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:17:55] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=6600
# [2026-06-12 02:17:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:20:24] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:20:24] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=7200
# [2026-06-12 02:20:25] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:27:39] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:27:39] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=7200
# [2026-06-12 02:27:40] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:34:26] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:34:26] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=7200
# [2026-06-12 02:34:27] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:38:58] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:38:58] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=7200
# [2026-06-12 02:38:59] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:41:50] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:41:50] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=7200
# [2026-06-12 02:41:51] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:44:00] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:44:00] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=7200
# [2026-06-12 02:44:01] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:45:30] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:45:30] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=7200
# [2026-06-12 02:45:31] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:47:14] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:47:14] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=7200
# [2026-06-12 02:47:15] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:49:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:49:38] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=7200
# [2026-06-12 02:49:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:52:14] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:52:14] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=7200
# [2026-06-12 02:52:15] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 02:54:42] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 02:54:42] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=7800
# [2026-06-12 02:54:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:04:21] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:04:21] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=7800
# [2026-06-12 03:04:22] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:12:32] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:12:32] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=7800
# [2026-06-12 03:12:33] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:18:07] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:18:07] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=7800
# [2026-06-12 03:18:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:21:37] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:21:37] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=7800
# [2026-06-12 03:21:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:24:07] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:24:07] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=7800
# [2026-06-12 03:24:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:25:45] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:25:45] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=7800
# [2026-06-12 03:25:46] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:27:36] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:27:36] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=7800
# [2026-06-12 03:27:37] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:29:50] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:29:50] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=7800
# [2026-06-12 03:29:51] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:32:19] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:32:19] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=7800
# [2026-06-12 03:32:20] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:35:09] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:35:09] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=8400
# [2026-06-12 03:35:10] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:45:54] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:45:54] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=8400
# [2026-06-12 03:45:55] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 03:54:29] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 03:54:29] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=8400
# [2026-06-12 03:54:30] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:01:04] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:01:04] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=8400
# [2026-06-12 04:01:05] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:05:22] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:05:22] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=8400
# [2026-06-12 04:05:23] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:08:01] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:08:01] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=8400
# [2026-06-12 04:08:02] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:09:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:09:38] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=8400
# [2026-06-12 04:09:38] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:11:23] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:11:23] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=8400
# [2026-06-12 04:11:24] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:13:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:13:38] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=8400
# [2026-06-12 04:13:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:15:34] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:15:34] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=8400
# [2026-06-12 04:15:35] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:18:02] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:18:02] 입력값 | main=3500, 직진비율=0.9, 진출비율=0.1, 유고 지속시간=9000
# [2026-06-12 04:18:03] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:29:55] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:29:55] 입력값 | main=3500, 직진비율=0.8, 진출비율=0.2, 유고 지속시간=9000
# [2026-06-12 04:29:56] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:39:38] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:39:38] 입력값 | main=3500, 직진비율=0.7, 진출비율=0.3, 유고 지속시간=9000
# [2026-06-12 04:39:39] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:46:53] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:46:53] 입력값 | main=3500, 직진비율=0.6, 진출비율=0.4, 유고 지속시간=9000
# [2026-06-12 04:46:54] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:51:49] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:51:49] 입력값 | main=3500, 직진비율=0.5, 진출비율=0.5, 유고 지속시간=9000
# [2026-06-12 04:51:49] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:55:25] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:55:25] 입력값 | main=3500, 직진비율=0.4, 진출비율=0.6, 유고 지속시간=9000
# [2026-06-12 04:55:26] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:57:17] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:57:17] 입력값 | main=3500, 직진비율=0.30000000000000004, 진출비율=0.7, 유고 지속시간=9000
# [2026-06-12 04:57:18] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 04:59:21] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 04:59:21] 입력값 | main=3500, 직진비율=0.19999999999999996, 진출비율=0.8, 유고 지속시간=9000
# [2026-06-12 04:59:22] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 05:01:42] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 05:01:42] 입력값 | main=3500, 직진비율=0.09999999999999998, 진출비율=0.9, 유고 지속시간=9000
# [2026-06-12 05:01:43] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 05:04:07] VISSIM 시뮬레이션 실행 완료
# [2026-06-12 05:04:07] 입력값 | main=3500, 직진비율=0.0, 진출비율=1.0, 유고 지속시간=9000
# [2026-06-12 05:04:08] VISSIM 시뮬레이션 실행 중...
# [2026-06-12 05:06:52] VISSIM 시뮬레이션 실행 완료
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
