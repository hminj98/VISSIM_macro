# %%
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간"
network_file_name = r"화성~서울(140-유고지점)_260518.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(140-진출구간)_260518.inpx")

csv_path = r"C:\Users\alswl\Desktop\26.05.18"
csv_file_name = r"synthetic_scenarios_all_140_with_set_type(진출구간).csv"

# 유고 발생 시각
acc_start_time = 3600
###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)



csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 램프 유출 비율
    Q1_ramp_out_vehph = row["q1_ramp_out_vph_per_ratio"]
    Q2_ramp_out_vehph = row["q2_ramp_out_vph_per_ratio"]
    Q3_ramp_out_vehph = row["q3_ramp_out_vph_per_ratio"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    # 종단경사
    #grade_percent = row["grade_percent"] * 0.01

    # 유고 지속시간
    incident_duration_min = row["incident_duration_min"]

    # 유고 차로수
    lane_closure_count = int(row["lane_closure_count"])

    # 랜덤시드
    random_seed = int(row["random_seed"])

    # 유고 발생 지점

    incident_location = row["location_name"]
    locations = [x.strip() for x in incident_location.split(",")] # [본선1, 본선2]
    location = locations[0]

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))

    # 램프 유출 비율
    for routing_decision  in root.findall(".//vehicleRoutingDecisionStatic"):
        decision_no = routing_decision.get("no")

        # decision별 Q값 매핑
        if decision_no == "1":
            Q = Q1_ramp_out_vehph
        elif decision_no == "2":
            Q = Q2_ramp_out_vehph
        elif decision_no == "3":
            Q = Q3_ramp_out_vehph
        else:
            continue

        veh_routes = routing_decision.find("vehRoutSta")
        if veh_routes is None:
            continue

        for route in veh_routes.findall("vehicleRouteStatic"):
            route_no = route.get("no")

            if route_no == "1":  # 직진
                route.set("relFlow", f"2 0:{round(1 - Q, 3)}")

            elif route_no == "2":  # 진출
                route.set("relFlow", f"2 0:{round(Q, 3)}")


    # 유고 발생 위치 조정
    for rsa in root.findall(".//reducedSpeedArea"):
        name = rsa.get("name")
        if name in locations:
            # 유고 지속시간 설정
            rsa.set("timeFrom", str(acc_start_time))
            rsa.set("timeTo", str(int(acc_start_time + incident_duration_min * 60)))


    # 랜덤시드 설정
    for rds in root.findall(".//simulation"):
        rds.set("randSeed", str(random_seed))


    print(
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}, seed={random_seed}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))


    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print("VISSIM 시뮬레이션 실행 중...")
    Vissim.Simulation.RunContinuous()
    print("VISSIM 시뮬레이션 실행 완료")

    # 파일 저장 완료 대기
    time.sleep(2)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# 입력값 | main=1444, ramp=106, seed=710527
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_001.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_001.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_001.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_002.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_002.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_002.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_003.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_003.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_003.mer
# 입력값 | main=1619, ramp=60, seed=479028
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_004.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_004.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_004.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_005.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_005.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_005.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_006.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_006.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_006.mer
# 입력값 | main=1118, ramp=45, seed=733248
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_007.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_007.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_007.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_008.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_008.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_008.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_009.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_009.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_009.mer
# 입력값 | main=1741, ramp=141, seed=229643
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_010.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_010.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_010.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_011.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_011.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_011.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_012.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_012.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_012.mer
# 입력값 | main=1785, ramp=131, seed=953814
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_013.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_013.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_013.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_014.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_014.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_014.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_015.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_015.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_015.mer
# 입력값 | main=1104, ramp=55, seed=870814
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_016.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_016.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_016.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_017.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_017.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_017.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_018.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_018.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_018.mer
# 입력값 | main=836, ramp=37, seed=491082
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_019.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_019.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_019.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_020.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_020.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_020.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_021.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_021.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_021.mer
# 입력값 | main=1308, ramp=34, seed=612956
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_022.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_022.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_022.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_023.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_023.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_023.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_024.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_024.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_024.mer
# 입력값 | main=1749, ramp=73, seed=122344
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_025.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_025.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_025.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_026.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_026.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_026.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_027.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_027.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_027.mer
# 입력값 | main=1408, ramp=83, seed=63492
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_028.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_028.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_028.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_029.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_029.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_029.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_030.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_030.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_030.mer
# 입력값 | main=1315, ramp=60, seed=672876
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_031.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_031.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_031.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_032.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_032.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_032.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_033.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_033.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_033.mer
# 입력값 | main=1722, ramp=169, seed=870128
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_034.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_034.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_034.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_035.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_035.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_035.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_036.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_036.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_036.mer
# 입력값 | main=796, ramp=79, seed=15583
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_037.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_037.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_037.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_038.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_038.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_038.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_039.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_039.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_039.mer
# 입력값 | main=1233, ramp=104, seed=777748
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_040.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_040.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_040.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_041.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_041.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_041.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_042.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_042.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_042.mer
# 입력값 | main=1362, ramp=88, seed=473963
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_043.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_043.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_043.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_044.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_044.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_044.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_045.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_045.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_045.mer
# 입력값 | main=1531, ramp=64, seed=480293
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_046.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_046.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_046.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_047.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_047.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_047.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_048.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_048.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_048.mer
# 입력값 | main=563, ramp=17, seed=77061
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_049.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_049.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_049.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_050.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_050.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_050.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_051.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_051.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_051.mer
# 입력값 | main=1586, ramp=75, seed=450962
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_052.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_052.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_052.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_053.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_053.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_053.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_054.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_054.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_054.mer
# 입력값 | main=1424, ramp=131, seed=327731
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_055.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_055.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_055.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_056.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_056.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_056.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_057.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_057.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_057.mer
# 입력값 | main=1374, ramp=67, seed=95657
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_058.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_058.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_058.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_059.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_059.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_059.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_060.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_060.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_060.mer
# 입력값 | main=674, ramp=22, seed=614954
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_061.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_061.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_061.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_062.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_062.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_062.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_063.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_063.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_063.mer
# 입력값 | main=1650, ramp=111, seed=301602
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_064.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_064.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_064.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_065.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_065.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_065.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_066.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_066.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_066.mer
# 입력값 | main=1729, ramp=84, seed=888433
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_067.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_067.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_067.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_068.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_068.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_068.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_069.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_069.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_069.mer
# 입력값 | main=721, ramp=37, seed=886210
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_070.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_070.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_070.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_071.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_071.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_071.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_072.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_072.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_072.mer
# 입력값 | main=1648, ramp=162, seed=30360
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_073.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_073.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_073.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_074.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_074.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_074.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_075.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_075.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_075.mer
# 입력값 | main=869, ramp=40, seed=593831
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_076.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_076.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_076.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_077.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_077.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_077.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_078.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_078.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_078.mer
# 입력값 | main=1320, ramp=40, seed=394469
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_079.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_079.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_079.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_080.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_080.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_080.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_081.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_081.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_081.mer
# 입력값 | main=1359, ramp=80, seed=163138
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_082.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_082.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_082.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_083.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_083.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_083.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_084.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_084.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_084.mer
# 입력값 | main=822, ramp=67, seed=636566
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_085.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_085.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_085.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_086.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_086.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_086.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_087.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_087.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_087.mer
# 입력값 | main=1405, ramp=79, seed=711164
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_088.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_088.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_088.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_089.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_089.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_089.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_090.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_090.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_090.mer
# 입력값 | main=1714, ramp=106, seed=8061
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_091.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_091.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_091.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_092.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_092.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_092.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_093.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_093.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_093.mer
# 입력값 | main=2819, ramp=229, seed=416360
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_094.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_094.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_094.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_095.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_095.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_095.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_096.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_096.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_096.mer
# 입력값 | main=1887, ramp=109, seed=743964
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_097.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_097.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_097.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_098.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_098.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_098.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_099.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_099.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_099.mer
# 입력값 | main=2656, ramp=124, seed=872443
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_100.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_100.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_100.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_101.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_101.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_101.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_102.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_102.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_102.mer
# 입력값 | main=2542, ramp=80, seed=414992
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_103.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_103.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_103.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_104.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_104.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_104.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_105.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_105.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_105.mer
# 입력값 | main=2436, ramp=198, seed=556380
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_106.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_106.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_106.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_107.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_107.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_107.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_108.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_108.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_108.mer
# 입력값 | main=2100, ramp=93, seed=997503
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_109.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_109.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_109.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_110.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_110.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_110.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_111.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_111.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_111.mer
# 입력값 | main=2812, ramp=169, seed=158291
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_112.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_112.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_112.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_113.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_113.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_113.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_114.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_114.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_114.mer
# 입력값 | main=2701, ramp=81, seed=531982
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_115.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_115.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_115.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_116.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_116.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_116.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_117.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_117.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_117.mer
# 입력값 | main=2839, ramp=154, seed=953208
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_118.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_118.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_118.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_119.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_119.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_119.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_120.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_120.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_120.mer
# 입력값 | main=2971, ramp=220, seed=108530
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_121.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_121.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_121.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_122.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_122.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_122.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_123.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_123.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_123.mer
# 입력값 | main=2504, ramp=247, seed=549526
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_124.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_124.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_124.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_125.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_125.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_125.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_126.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_126.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_126.mer
# 입력값 | main=2871, ramp=203, seed=827565
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_127.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_127.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_127.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_128.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_128.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_128.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_129.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_129.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_129.mer
# 입력값 | main=2486, ramp=75, seed=349556
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_130.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_130.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_130.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_131.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_131.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_131.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_132.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_132.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_132.mer
# 입력값 | main=1967, ramp=135, seed=135216
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_133.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_133.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_133.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_134.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_134.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_134.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_135.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_135.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_135.mer
# 입력값 | main=1974, ramp=95, seed=677407
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_136.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_136.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_136.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_137.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_137.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_137.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_138.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_138.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_138.mer
# 입력값 | main=2668, ramp=168, seed=201333
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_139.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_139.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_139.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_140.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_140.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_140.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_141.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_141.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_141.mer
# 입력값 | main=2069, ramp=145, seed=45815
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_142.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_142.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_142.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_143.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_143.parquet
# ...
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_283.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_284.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_284.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_284.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_285.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_285.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_285.mer
# 입력값 | main=3801, ramp=407, seed=97252
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_286.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_286.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_286.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_287.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_287.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_287.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_288.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_288.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_288.mer
# 입력값 | main=3824, ramp=295, seed=82628
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_289.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_289.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_289.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_290.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_290.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_290.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_291.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_291.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_291.mer
# 입력값 | main=3960, ramp=382, seed=83668
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_292.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_292.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_292.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_293.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_293.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_293.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_294.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_294.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_294.mer
# 입력값 | main=3825, ramp=301, seed=735912
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_295.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_295.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_295.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_296.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_296.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_296.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_297.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_297.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_297.mer
# 입력값 | main=3955, ramp=386, seed=883795
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_298.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_298.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_298.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_299.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_299.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_299.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_300.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_300.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_300.mer
# 입력값 | main=3858, ramp=430, seed=687278
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_301.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_301.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_301.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_302.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_302.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_302.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_303.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_303.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_303.mer
# 입력값 | main=3670, ramp=186, seed=625381
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_304.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_304.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_304.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_305.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_305.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_305.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_306.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_306.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_306.mer
# 입력값 | main=3797, ramp=167, seed=805935
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_307.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_307.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_307.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_308.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_308.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_308.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_309.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_309.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_309.mer
# 입력값 | main=3657, ramp=145, seed=912805
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_310.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_310.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_310.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_311.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_311.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_311.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_312.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_312.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_312.mer
# 입력값 | main=3859, ramp=214, seed=20423
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_313.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_313.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_313.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_314.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_314.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_314.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_315.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_315.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_315.mer
# 입력값 | main=3785, ramp=261, seed=767461
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_316.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_316.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_316.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_317.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_317.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_317.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_318.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_318.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_318.mer
# 입력값 | main=3435, ramp=254, seed=553307
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_319.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_319.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_319.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_320.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_320.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_320.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_321.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_321.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_321.mer
# 입력값 | main=3461, ramp=130, seed=74442
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_322.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_322.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_322.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_323.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_323.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_323.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_324.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_324.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_324.mer
# 입력값 | main=3908, ramp=239, seed=98908
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_325.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_325.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_325.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_326.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_326.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_326.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_327.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_327.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_327.mer
# 입력값 | main=3906, ramp=227, seed=422180
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_328.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_328.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_328.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_329.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_329.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_329.mer
# [변환 시작] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_330.mer
# [저장 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_330.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random)_260518\진출구간\화성~서울(140-진출구간)_260518_330.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
