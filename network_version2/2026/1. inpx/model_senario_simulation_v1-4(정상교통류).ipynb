# %%
"""
    정상교통류 STVM 재분석
"""
import glob
import shutil
import time

import win32com.client  # Windows COM 인터페이스 사용
import xml.etree.ElementTree as ET
import pandas as pd

import os.path

# 입력 파라미터
###################################################################################################################
network_path = r"C:\Vissim_Workspace\STVM 재분석"
network_file_name = r"화성~서울(정상교통류)_260528.inpx"
network_full_path = os.path.join(network_path, network_file_name)

copy_network_path = os.path.join(network_path, f"화성~서울(정상교통류 분석)_260528.inpx")

csv_path = r"C:\Users\alswl\Desktop\26.05.18"
csv_file_name = r"정상교통류 시나리오_260528.csv"

###################################################################################################################
# =========================================================
# .mer → parquet 변환 함수
# =========================================================
def convert_mer_to_parquet(mer_file, delete_original=True):
    try:
        print(f"[변환 시작] {mer_file}")

        with open(mer_file, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()

        data_start_idx = None
        for i, line in enumerate(lines):
            if "Measurem." in line:
                data_start_idx = i
                break

        if data_start_idx is None:
            print(f"[건너뜀] 데이터 헤더를 찾지 못함: {mer_file}")
            return

        df = pd.read_csv(
            mer_file,
            sep=";",
            skiprows=data_start_idx,
            encoding="utf-8",
            engine="python"
        )

        df.columns = [str(col).strip() for col in df.columns]

        parquet_path = mer_file.replace(".mer", ".parquet")

        df.to_parquet(
            parquet_path,
            engine="pyarrow",
            compression="snappy",
            index=False
        )

        print(f"[저장 완료] {parquet_path}")

        if delete_original:
            os.remove(mer_file)
            print(f"[원본 삭제 완료] {mer_file}")

    except Exception as e:
        print(f"[변환 실패] {mer_file}")
        print(e)


csv_full_path  = os.path.join(csv_path, csv_file_name)

# 시나리오 파일 읽기
senario_df = pd.read_csv(csv_full_path, encoding="cp949")

Vissim = win32com.client.Dispatch("Vissim.Vissim")  # Vissim 인스턴스 생성

for index, row in senario_df.iterrows():

    # 교통량
    Q_main_in_vehph = row["base_main_in_vph"]
    Q_ramp_in_per_ramp = row["q_ramp_in_vph_per"]

    # 본선 유입 중차량 비율
    V1_main_in_ratio = row["V1_main_in_ratio"]
    V2_main_in_ratio = row["V2_main_in_ratio"]
    V3_main_in_ratio = row["V3_main_in_ratio"]
    V4_main_in_ratio = row["V4_main_in_ratio"]
    V5_main_in_ratio = max(row["V5_main_in_ratio"], 0.001)

    # 램프 유입 중차량 비율
    V1_ramp_in_ratio = row["V1_ramp_in_ratio"]
    V2_ramp_in_ratio = row["V2_ramp_in_ratio"]
    V3_ramp_in_ratio = row["V3_ramp_in_ratio"]
    V4_ramp_in_ratio = row["V4_ramp_in_ratio"]
    V5_ramp_in_ratio = max(row["V5_ramp_in_ratio"], 0.001)

    shutil.copy(network_full_path, copy_network_path)

    # XML 로드
    tree = ET.parse(copy_network_path)
    root = tree.getroot()


    # 본선, 유입램프 교통량
    for vehicle_input in root.findall(".//vehicleInput"):
        input_name = vehicle_input.get("name")
        vehicleInput = vehicle_input.find("timeIntVehVols")

        if vehicleInput is None:
            continue
        for vol in vehicleInput.findall("timeIntervalVehVolume"):
            if input_name == "main":
                vol.set("volume", str(Q_main_in_vehph))
            elif input_name in ["ramp1-1", "ramp1-2"]:
                vol.set("volume", str(Q_ramp_in_per_ramp))

    # 본선/ 램프 유입 중차량 비율
    for vehicle_comp in root.findall(".//vehicleComposition"):
        if vehicle_comp.get("name") == "main":
            relflow_100 = V1_main_in_ratio
            relflow_300 = V2_main_in_ratio
            relflow_630 = V3_main_in_ratio
            relflow_640 = V4_main_in_ratio
            relflow_650 = V5_main_in_ratio

        elif vehicle_comp.get("name") == "ramp":
            relflow_100 = V1_ramp_in_ratio
            relflow_300 = V2_ramp_in_ratio
            relflow_630 = V3_ramp_in_ratio
            relflow_640 = V4_ramp_in_ratio
            relflow_650 = V5_ramp_in_ratio
        else:
            continue
        # <vehCompRelFlows> 태그 찾기
        vehCompRelFlows = vehicle_comp.find("vehCompRelFlows")
        if vehCompRelFlows is not None:
            # <vehicleCompositionRelativeFlow> 태그 찾기
            for relflow in vehCompRelFlows.findall("vehicleCompositionRelativeFlow"):
                vehType = relflow.get("vehType")
                if vehType == "100": # 승용차
                    relflow.set("relFlow", str(relflow_100))
                elif vehType == "300": # 버스
                    relflow.set("relFlow", str(relflow_300))
                elif vehType == "630": # 소형화물
                    relflow.set("relFlow", str(relflow_630))
                elif vehType == "640": # 중형화물
                    relflow.set("relFlow", str(relflow_640))
                elif vehType == "650": # 대형화물
                    relflow.set("relFlow", str(relflow_650))


    print(
        f"입력값 | main={Q_main_in_vehph}, ramp={Q_ramp_in_per_ramp}"
    )


    tree.write(copy_network_path, encoding="utf-8", xml_declaration=True)
    before_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))


    # VISSIM 네트워크 로드
    Vissim.LoadNet(copy_network_path)
    Vissim.Graphics.CurrentNetworkWindow.SetAttValue('QuickMode', 1) # 퀵 모드 활성화

    print("VISSIM 시뮬레이션 실행 중...")
    Vissim.Simulation.RunContinuous()
    print("VISSIM 시뮬레이션 실행 완료")

    # 파일 저장 완료 대기
    time.sleep(2)

    # 시뮬레이션 후 새로 생성된 mer만 변환
    after_mer_files = set(glob.glob(os.path.join(network_path, "*.mer")))
    new_mer_files = sorted(list(after_mer_files - before_mer_files))

    if len(new_mer_files) == 0:
        print("[주의] 새로 생성된 .mer 파일을 찾지 못했습니다.")
    else:
        for mer_file in new_mer_files:
            convert_mer_to_parquet(mer_file, delete_original=True)

Vissim.Simulation.Stop()
Vissim.Exit()
print("VISSIM 시뮬레이션 종료")
print("==============================================================================================================")
# Out:
# 입력값 | main=2000.0, ramp=600.0
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_001.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_001.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_001.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_002.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_002.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_002.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_003.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_003.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_003.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_004.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_004.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_004.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_005.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_005.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_005.mer
# 입력값 | main=5000.0, ramp=600.0
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_006.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_006.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_006.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_007.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_007.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_007.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_008.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_008.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_008.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_009.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_009.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_009.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_010.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_010.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_010.mer
# 입력값 | main=6000.0, ramp=600.0
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_011.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_011.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_011.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_012.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_012.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_012.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_013.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_013.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_013.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_014.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_014.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_014.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_015.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_015.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_015.mer
# 입력값 | main=4000.0, ramp=1000.0
# VISSIM 시뮬레이션 실행 중...
# VISSIM 시뮬레이션 실행 완료
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_016.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_016.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_016.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_017.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_017.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_017.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_018.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_018.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_018.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_019.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_019.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_019.mer
# [변환 시작] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_020.mer
# [저장 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_020.parquet
# [원본 삭제 완료] C:\Vissim_Workspace\STVM 재분석\화성~서울(정상교통류 분석)_260528_020.mer
# VISSIM 시뮬레이션 종료
# ==============================================================================================================
