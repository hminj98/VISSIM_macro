# %%
import os

import pandas as pd

path = r"E:\2026년\1. 초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발\VISSIM_Workspace\Test"
mer_list = sorted([file for file in os.listdir(path) if file.endswith(".parquet")])
print(mer_list)
for idx, start in enumerate(range(0, len(mer_list))):
    file = os.path.join(path, mer_list[idx])
    print(file)
    df=pd.read_parquet(file)
    display(df)
# Out:
# ['화성~서울(140-진입구간)_260518_001.parquet', '화성~서울(140-진입구간)_260518_002.parquet', '화성~서울(140-진입구간)_260518_003.parquet']
# E:\2026년\1. 초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발\VISSIM_Workspace\Test\화성~서울(140-진입구간)_260518_001.parquet
#          Measurem.  t(Entry)  t(Exit)  VehNo  Vehicle type  Line  v[km/h]  \
# 0            10001   1800.03    -1.00    826           100     0     92.7
# 1            10039     -1.00  1800.09    747           100     0     86.2
# 2            10060   1800.02    -1.00    706           100     0     85.6
# 3            10066   1800.09    -1.00    689           100     0     87.0
# 4            10074   1800.05    -1.00    671           100     0     86.7
# ...            ...       ...      ...    ...           ...   ...      ...
# 2436896      20095  13199.99    -1.00   5986           300     0     85.0
# 2436897      20135  13200.00    -1.00   5903           100     0     86.7
# 2436898      20161  13199.97    -1.00   5848           100     0     85.0
# ...
