# %%
import os
import gc
from itertools import zip_longest
from datetime import datetime
import xml.etree.ElementTree as ET

import numpy as np
import pandas as pd


"""
ToyNetwork 재분석
- 원본 parquet를 매번 다시 groupby/merge하지 않도록
  sec_time별 processed parquet를 먼저 생성한 뒤 분석에 재사용하는 구조
    최종 수정본
본선부 1
"""


# =============================================================================
# 1. 입력값 설정
# =============================================================================
path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간1"

senario_path = r"C:\Users\alswl\Desktop\유고 시나리오\검증용 시나리오\synthetic_scenarios_all_140_with_set_type(본선부-구간1).csv"

inpx_path = r"C:\Vissim_Workspace\시나리오(140-유고지점 Uniform Random, 검증용)_260610\본선부\구간1\화성~서울(140-유고지점)_260526.inpx"


# 한 시나리오당 seed 파일 수
num_mer = 3

# 임계 연속 시간: 초 단위
continuous_list = [180]

# 집계시간: 초 단위
sec_time_list = [10,20,30]
# sec_time_list = [10, 20, 30]

# 상류 검지기 위치
up_dcp_pos_list = [0,1,2,3,4]

start_interval = 1800
end_use_interval = 12600
end_interval = 13200

acc_start_time = 3600
Vc = 53.7

weights = {
    "w1": 1,
    "w2": 1,
    "w3": 1,
    "w4": 1,
    "w5": 1,
    "w6": 1,
}

vehicle_types = [100, 300, 630, 640, 650]

# 램프 관련 검지기
before_ramp = [70, 117, 124, 186, 215]
after_ramp = [74, 121, 127, 190, 221]
input_ramp = [902, 904]
output_ramp = [901, 903, 905]

enter_line = [23, 121, 190]
input_main_ramp = [121, 190]
output_main_ramp = [73, 126, 220]

three_lane = [71, 72, 73, 119, 120, 125, 126, 188, 189, 216, 217, 218, 219, 220]

# 전역 변수: 반복문 내부에서 갱신
revision_time = None
sec_time = None
up_dcp_pos = None
continuous_n = None

lane = None
acc_lane = None
acc_finish_time = None
lane_gradient = None
incident_measurement = None

detector_map = {}


# =============================================================================
# 2. 공통 함수
# =============================================================================
def sort_ascending(df):
    df = df.copy()
    df["StartTime"] = (
        df["TimeGroup"].astype(str).str.split("~").str[0].astype(int)
    )
    df["EndTime"] = (
        df["TimeGroup"].astype(str).str.split("~").str[1].astype(int)
    )
    df = df.sort_values(["StartTime", "EndTime", "New_Measurement"]).reset_index(drop=True)
    return df


def complete_time_measurement(df, value_cols, measurements=None):
    df = df.copy()

    full_time = pd.DataFrame({
        "StartTime": np.arange(start_interval, end_interval, sec_time)
    })
    full_time["EndTime"] = full_time["StartTime"] + sec_time
    full_time["TimeGroup"] = (
        full_time["StartTime"].astype(str) + "~" + full_time["EndTime"].astype(str)
    )

    if measurements is None:
        measurements = sorted(df["New_Measurement"].dropna().unique())

    measurement_df = pd.DataFrame({"New_Measurement": measurements})

    full_index = (
        full_time.assign(key=1)
        .merge(measurement_df.assign(key=1), on="key")
        .drop(columns="key")
    )

    df = full_index.merge(
        df,
        on=["TimeGroup", "New_Measurement"],
        how="left"
    )

    for col in value_cols:
        if col in df.columns:
            df[col] = df[col].fillna(0)

    df = sort_ascending(df)
    return df


def add_time_group(original_df):
    original_df = original_df.copy()

    bins = np.arange(start_interval, end_interval + 1, sec_time)
    labels = [f"{start}~{start + sec_time}" for start in bins[:-1]]

    original_df["TimeGroup"] = pd.cut(
        original_df["t(Entry)"],
        bins=bins,
        labels=labels,
        right=False
    )

    original_df = original_df[original_df["TimeGroup"].notna()].copy()
    original_df["TimeGroup"] = original_df["TimeGroup"].astype(str)

    return original_df


# =============================================================================
# 3. 지표 계산 함수
# =============================================================================
def speed_mean(original_df):
    copy_df = original_df.copy()
    copy_df = copy_df[~copy_df["New_Measurement"].between(900, 910)]

    measurements = sorted(copy_df["New_Measurement"].dropna().unique())

    speed_mean_df = (
        copy_df.groupby(["TimeGroup", "New_Measurement"])
        .agg(
            V_mean=("v[km/h]", "mean"),
            V_count=("v[km/h]", "count")
        )
        .reset_index()
    )

    speed_mean_df = complete_time_measurement(
        speed_mean_df,
        value_cols=["V_mean", "V_count"],
        measurements=measurements
    )

    # 다음 검지기 속도
    speed_mean_df["V_next"] = speed_mean_df.groupby("TimeGroup")["V_mean"].shift(-1)

    cols = ["V_mean", "V_next"]
    speed_mean_df[cols] = speed_mean_df[cols].fillna(0)

    speed_mean_df["delta_V"] = np.where(
        speed_mean_df["V_mean"] == 0,
        0,
        (speed_mean_df["V_next"] - speed_mean_df["V_mean"]) / speed_mean_df["V_mean"]
    )

    return speed_mean_df


def density_mean(speed_df):
    density_mean_df = speed_df.copy()

    density_mean_df["K"] = np.where(
        density_mean_df["V_mean"] == 0,
        0,
        density_mean_df["V_count"] * revision_time / density_mean_df["V_mean"]
    )

    density_mean_df["K_next"] = density_mean_df.groupby("TimeGroup")["K"].shift(-1)

    cols = ["K", "K_next"]
    density_mean_df[cols] = density_mean_df[cols].fillna(0)

    density_mean_df["delta_K"] = np.where(
        density_mean_df["K"] == 0,
        0,
        (density_mean_df["K_next"] - density_mean_df["K"]) / density_mean_df["K"]
    )

    density_mean_df = complete_time_measurement(
        density_mean_df,
        value_cols=["V_mean", "V_count", "K", "K_next", "delta_K"]
    )

    return density_mean_df


def heavy_rate(original_df):
    copy_df = original_df.copy()
    measurements = sorted(copy_df["New_Measurement"].dropna().unique())

    heavy_df = (
        copy_df.groupby(["TimeGroup", "New_Measurement"])
        .agg(
            heavy_count=("Vehicle type", lambda x: x.isin([630, 640, 650]).sum()),
            total_count=("Vehicle type", "count")
        )
        .reset_index()
    )

    heavy_df = sort_ascending(heavy_df)

    heavy_df = complete_time_measurement(
        heavy_df,
        value_cols=["heavy_count", "total_count"],
        measurements=measurements
    )

    heavy_df["rate"] = np.where(
        heavy_df["total_count"] == 0,
        0,
        heavy_df["heavy_count"] / heavy_df["total_count"]
    )

    return heavy_df


def entry_saturation(original_df):
    copy_df = original_df.copy()
    copy_df = copy_df[~copy_df["New_Measurement"].between(900, 910)]

    measurements = sorted(copy_df["New_Measurement"].dropna().unique())

    entry_saturation_df = (
        copy_df.groupby(["TimeGroup", "New_Measurement"])
        .size()
        .reset_index(name="entry_volume")
    )

    entry_saturation_df = complete_time_measurement(
        entry_saturation_df,
        value_cols=["entry_volume"],
        measurements=measurements
    )

    entry_saturation_df = sort_ascending(entry_saturation_df)

    entry_saturation_df["capacity"] = np.where(
        entry_saturation_df["New_Measurement"].isin(three_lane),
        5100,
        3400
    )

    entry_saturation_df["Phi_진입"] = (
        entry_saturation_df["entry_volume"] * revision_time / entry_saturation_df["capacity"]
    )

    return entry_saturation_df


def rfr_rate(original_df):
    copy_df = original_df.copy()
    copy_df = copy_df[copy_df["TimeGroup"].notna()]
    copy_df["TimeGroup"] = copy_df["TimeGroup"].astype(str)

    main_results = []

    for before, after in zip(before_ramp, after_ramp):
        q_before = (
            copy_df[copy_df["New_Measurement"] == before]
            .groupby("TimeGroup")
            .size()
            .reset_index(name="q_before")
        )

        q_after = (
            copy_df[copy_df["New_Measurement"] == after]
            .groupby("TimeGroup")
            .size()
            .reset_index(name="q_after")
        )

        merged = q_before.merge(q_after, on="TimeGroup", how="outer").fillna(0)
        merged["before_ramp"] = before
        merged["after_ramp"] = after
        merged["Qm"] = (merged["q_before"] + merged["q_after"]) / 2
        main_results.append(merged)

    ramp_results = []

    for input_, output_ in zip_longest(input_ramp, output_ramp):
        if output_ is not None:
            q_out = (
                copy_df[copy_df["New_Measurement"] == output_]
                .groupby("TimeGroup")
                .size()
                .reset_index(name="q_out")
            )
            q_out["New_Measurement"] = output_
            ramp_results.append(q_out)

        if input_ is not None:
            q_in = (
                copy_df[copy_df["New_Measurement"] == input_]
                .groupby("TimeGroup")
                .size()
                .reset_index(name="q_in")
            )
            q_in["New_Measurement"] = input_
            ramp_results.append(q_in)

    input_queue = input_main_ramp.copy()
    output_queue = output_main_ramp.copy()
    rfr_list = []

    for i in range(min(len(main_results), len(ramp_results))):
        main_df = main_results[i]
        ramp_df = ramp_results[i]

        rfr_df = pd.merge(main_df, ramp_df, on="TimeGroup", how="outer").fillna(0)

        rfr_df["IR_in"] = 0
        rfr_df["IR_out"] = 0

        if "q_in" in rfr_df.columns:
            rfr_df["IR_in"] = np.where(
                rfr_df["Qm"] == 0,
                0,
                rfr_df["q_in"] / rfr_df["Qm"]
            )
            if input_queue:
                current_input = input_queue.pop(0)
                rfr_df["New_Measurement"] = current_input

        if "q_out" in rfr_df.columns:
            rfr_df["IR_out"] = np.where(
                rfr_df["Qm"] == 0,
                0,
                rfr_df["q_out"] / rfr_df["Qm"]
            )
            if output_queue:
                current_output = output_queue.pop(0)
                rfr_df["New_Measurement"] = current_output

        rfr_df["RFR"] = rfr_df["IR_in"] + rfr_df["IR_out"]
        rfr_list.append(rfr_df)

    if not rfr_list:
        base = copy_df[["TimeGroup"]].drop_duplicates().copy()
        all_measurements = copy_df["New_Measurement"].unique()

        expanded = []
        for m in all_measurements:
            temp = base.copy()
            temp["New_Measurement"] = m
            temp["RFR"] = 0
            expanded.append(temp)

        final_rfr_df = pd.concat(expanded, ignore_index=True)
        final_rfr_df = final_rfr_df.sort_values(["TimeGroup", "New_Measurement"]).reset_index(drop=True)
        final_rfr_df["RFR"] = final_rfr_df["RFR"].fillna(0)

    else:
        final_rfr_df = pd.concat(rfr_list, ignore_index=True)

        target_measurements = input_main_ramp + output_main_ramp
        all_measurements = copy_df["New_Measurement"].unique()

        expanded_df_list = []
        base_rfr_df = final_rfr_df.copy()

        for m in all_measurements:
            if m in target_measurements:
                temp = base_rfr_df[base_rfr_df["New_Measurement"] == m].copy()
            else:
                temp = base_rfr_df[["TimeGroup"]].drop_duplicates().copy()
                temp["New_Measurement"] = m
                temp["RFR"] = 0

            expanded_df_list.append(temp)

        final_rfr_df = pd.concat(expanded_df_list, ignore_index=True)
        final_rfr_df = final_rfr_df.sort_values(["TimeGroup", "New_Measurement"]).reset_index(drop=True)
        final_rfr_df = final_rfr_df[["TimeGroup", "New_Measurement", "RFR"]]
        final_rfr_df["RFR"] = final_rfr_df["RFR"].fillna(0)

    final_rfr_df = sort_ascending(final_rfr_df)

    final_rfr_df = complete_time_measurement(
        final_rfr_df,
        value_cols=["RFR"]
    )

    return final_rfr_df


def output_normality(original_df):
    copy_df = original_df.copy()
    copy_df = copy_df[copy_df["TimeGroup"].notna()]

    normality_list = []

    for enter, exit_ramp, exit_main in zip(enter_line, output_ramp, output_main_ramp):
        entry_df = copy_df[copy_df["New_Measurement"] == enter][
            ["New_Measurement", "VehNo", "t(Entry)"]
        ]

        exit_df = copy_df[copy_df["New_Measurement"] == exit_ramp][
            ["New_Measurement", "VehNo", "t(Entry)"]
        ]

        entry_first = (
            entry_df.groupby("VehNo")["t(Entry)"]
            .min()
            .reset_index()
            .rename(columns={"t(Entry)": "t_entry"})
        )

        exit_first = (
            exit_df.groupby("VehNo")["t(Entry)"]
            .min()
            .reset_index()
            .rename(columns={"t(Entry)": "t_exit"})
        )

        merged = pd.merge(entry_first, exit_first, on="VehNo", how="inner")
        merged["delay_sec"] = merged["t_exit"] - merged["t_entry"]
        merged = merged[merged["delay_sec"] >= 0]

        if len(merged) and np.isfinite(np.nanmedian(merged["delay_sec"])):
            lag_bins = int(round(np.nanmedian(merged["delay_sec"]) / sec_time))
        else:
            lag_bins = 0

        entry_count = (
            copy_df[copy_df["New_Measurement"] == enter]
            .groupby("TimeGroup")
            .size()
            .reset_index(name="Q_in")
        )

        exit_count = (
            copy_df[copy_df["New_Measurement"] == exit_ramp]
            .groupby("TimeGroup")
            .size()
            .reset_index(name="Q_out")
        )

        merged_counts = pd.merge(entry_count, exit_count, on="TimeGroup", how="left")
        merged_counts["Q_out_shift"] = merged_counts["Q_out"].shift(-lag_bins)

        merged_counts["F(outrate)"] = np.where(
            merged_counts["Q_in"] == 0,
            0,
            merged_counts["Q_out_shift"] / merged_counts["Q_in"]
        )

        merged_counts["New_Measurement"] = exit_main
        normality_list.append(merged_counts)

    if not normality_list:
        base = copy_df[["TimeGroup"]].drop_duplicates().copy()
        all_measurements = copy_df["New_Measurement"].unique()

        expanded = []
        for m in all_measurements:
            temp = base.copy()
            temp["New_Measurement"] = m
            temp["F(outrate)"] = 0
            expanded.append(temp)

        final_df = pd.concat(expanded, ignore_index=True)
        final_df = final_df.sort_values(["TimeGroup", "New_Measurement"]).reset_index(drop=True)
        final_df["F(outrate)"] = final_df["F(outrate)"].fillna(0)

    else:
        final_df = pd.concat(normality_list, ignore_index=True)

        all_measurements = copy_df["New_Measurement"].unique()
        expanded_list = []

        for m in all_measurements:
            if m in output_main_ramp:
                temp = final_df[final_df["New_Measurement"] == m].copy()
            else:
                temp = final_df[["TimeGroup"]].drop_duplicates().copy()
                temp["New_Measurement"] = m
                temp["F(outrate)"] = 0

            expanded_list.append(temp)

        final_df = pd.concat(expanded_list, ignore_index=True)
        final_df = final_df.sort_values(["TimeGroup", "New_Measurement"]).reset_index(drop=True)

    final_df = sort_ascending(final_df)

    final_df = complete_time_measurement(
        final_df,
        value_cols=["F(outrate)"]
    )

    return final_df


def calculate_stvm(speed_df, density_df, heavy_df, entry_saturation_df, rfr_df, normality_df):
    merged_df = (
        speed_df[["TimeGroup", "New_Measurement", "delta_V"]]
        .merge(
            density_df[["TimeGroup", "New_Measurement", "delta_K"]],
            on=["TimeGroup", "New_Measurement"],
            how="outer"
        )
        .merge(
            heavy_df[["TimeGroup", "New_Measurement", "rate"]],
            on=["TimeGroup", "New_Measurement"],
            how="outer"
        )
        .merge(
            entry_saturation_df[["TimeGroup", "New_Measurement", "Phi_진입"]],
            on=["TimeGroup", "New_Measurement"],
            how="outer"
        )
        .merge(
            rfr_df[["TimeGroup", "New_Measurement", "RFR"]],
            on=["TimeGroup", "New_Measurement"],
            how="outer"
        )
        .merge(
            normality_df[["TimeGroup", "New_Measurement", "F(outrate)"]],
            on=["TimeGroup", "New_Measurement"],
            how="outer"
        )
    )

    merged_df.fillna(0, inplace=True)

    merged_df["STVM"] = (
        weights["w1"] * merged_df["delta_V"]
        + weights["w2"] * merged_df["delta_K"]
        + weights["w3"] * merged_df["rate"]
        + weights["w4"] * merged_df["Phi_진입"]
        + weights["w5"] * merged_df["RFR"]
        + weights["w6"] * merged_df["F(outrate)"]
    )

    merged_df.replace([np.inf, -np.inf], 0, inplace=True)
    merged_df = modify_frame(merged_df)

    return merged_df


def modify_frame(df):
    modify_df = df.copy()

    if "StartTime" not in modify_df.columns or "EndTime" not in modify_df.columns:
        modify_df["StartTime"] = modify_df["TimeGroup"].str.split("~").str[0].astype(int)
        modify_df["EndTime"] = modify_df["TimeGroup"].str.split("~").str[1].astype(int)

    modify_df = modify_df[
        (modify_df["StartTime"] >= start_interval)
        & (modify_df["EndTime"] <= end_use_interval)
    ]

    modify_df = modify_df[~modify_df["New_Measurement"].isin([266, 901, 902, 903, 904, 905])]
    modify_df = modify_df.sort_values(["StartTime", "New_Measurement"]).reset_index(drop=True)

    return modify_df


# =============================================================================
# 4. processed parquet 생성
# =============================================================================
def build_processed_file(raw_file_path, processed_file_path):
    use_cols = ["Measurem.", "t(Entry)", "v[km/h]", "Vehicle type", "VehNo"]

    df = pd.read_parquet(raw_file_path, columns=use_cols)
    df = df.apply(pd.to_numeric, errors="coerce")

    original_df = df[df["t(Entry)"] != -1.00].reset_index(drop=True)
    original_df.drop(columns=["b[m/s2]", "tQueue", "Occ", "Pers"], inplace=True, errors="ignore")
    original_df["New_Measurement"] = original_df["Measurem."] % 1000

    original_df = add_time_group(original_df)

    speed_df = speed_mean(original_df)
    density_df = density_mean(speed_df)
    heavy_df = heavy_rate(original_df)
    entry_df = entry_saturation(original_df)
    rfr_df = rfr_rate(original_df)
    normality_df = output_normality(original_df)
    stvm_df = calculate_stvm(speed_df, density_df, heavy_df, entry_df, rfr_df, normality_df)

    processed_df = (
        speed_df[[
            "StartTime", "EndTime", "TimeGroup", "New_Measurement",
            "V_mean", "V_count", "V_next", "delta_V"
        ]]
        .merge(
            density_df[["TimeGroup", "New_Measurement", "K", "K_next", "delta_K"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
        .merge(
            heavy_df[["TimeGroup", "New_Measurement", "rate"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
        .merge(
            entry_df[["TimeGroup", "New_Measurement", "Phi_진입"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
        .merge(
            rfr_df[["TimeGroup", "New_Measurement", "RFR"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
        .merge(
            normality_df[["TimeGroup", "New_Measurement", "F(outrate)"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
        .merge(
            stvm_df[["TimeGroup", "New_Measurement", "STVM"]],
            on=["TimeGroup", "New_Measurement"],
            how="left"
        )
    )

    processed_df = modify_frame(processed_df)
    processed_df = processed_df.fillna(0)

    processed_df.to_parquet(processed_file_path, index=False)

    del df, original_df
    del speed_df, density_df, heavy_df, entry_df, rfr_df, normality_df, stvm_df, processed_df
    gc.collect()


def build_processed_files(folder_path, parquet_list, processed_folder, overwrite=False):
    os.makedirs(processed_folder, exist_ok=True)

    for mer_file in parquet_list:
        raw_file_path = os.path.join(folder_path, mer_file)
        processed_name = f"processed_{sec_time}sec_{mer_file}"
        processed_file_path = os.path.join(processed_folder, processed_name)

        if os.path.exists(processed_file_path) and not overwrite:
            continue

        print(f"processed 생성: {processed_name}")
        build_processed_file(raw_file_path, processed_file_path)


# =============================================================================
# 5. 분석 함수
# =============================================================================
def get_upstream_detector(root, location):
    detector_no = None
    detector_link = None
    gradient = None

    rsa_lane = None
    rsa_pos = None
    best_pos = -1

    for rsa in root.findall(".//reducedSpeedArea"):
        if rsa.get("name") == location:
            rsa_lane = rsa.get("lane")
            rsa_pos = float(rsa.get("pos"))

            for dcp in root.findall(".//dataCollectionPoint"):
                if dcp.get("lane") == rsa_lane:
                    dcp_pos = float(dcp.get("pos"))

                    if rsa_pos >= dcp_pos >= best_pos:
                        best_pos = dcp_pos
                        detector_no = int(dcp.get("no")) % 1000 - up_dcp_pos
                        detector_link = detector_map.get(detector_no)

    if detector_no is None:
        print("링크 번호가 다름")
        best_pos = float("inf")

        for dcp in root.findall(".//dataCollectionPoint"):
            if dcp.get("lane") == rsa_lane:
                dcp_pos = float(dcp.get("pos"))

                if rsa_pos < dcp_pos < best_pos:
                    best_pos = dcp_pos
                    detector_no = int(dcp.get("no")) % 1000 - 1 - up_dcp_pos
                    detector_link = detector_map.get(detector_no)

    for link in root.findall(".//link"):
        if int(link.get("no")) == detector_link:
            gradient = round(float(link.get("gradient")), 4)
            break

    return detector_no, gradient


def calculate_logD(speed_avg, entry_avg, heavy_avg, stvm_avg):
    speed_df = speed_avg.copy()
    entry_df = entry_avg.copy()
    heavy_df = heavy_avg.copy()
    stvm_df = stvm_avg.copy()

    speed_after = (
        speed_df[
            (speed_df["New_Measurement"] == incident_measurement)
            & (speed_df["StartTime"] >= acc_start_time)
        ]
        .sort_values("StartTime")
        .reset_index(drop=True)
    )

    speed_after["is_congested"] = speed_after["V_mean"] <= Vc

    T2 = None

    for i in range(len(speed_after) - continuous_n + 1):
        if speed_after.loc[i:i + continuous_n - 1, "is_congested"].all():
            T2 = speed_after.loc[i + continuous_n - 1, "EndTime"]
            break

    if T2 is None:
        dc = np.nan
    else:
        dc = (T2 - acc_start_time) / 60
        if dc == 0:
            dc = np.nan

    print("dc:", dc)

    el = lane - acc_lane

    before_group = f"{acc_start_time - sec_time}~{acc_start_time}"
    after_group = f"{acc_start_time}~{acc_start_time + sec_time}"

    s_before = entry_df.loc[
        (entry_df["TimeGroup"] == before_group)
        & (entry_df["New_Measurement"] == incident_measurement),
        "Phi_진입"
    ].iloc[0]

    hv = heavy_df.loc[
        (heavy_df["TimeGroup"] == after_group)
        & (heavy_df["New_Measurement"] == incident_measurement),
        "rate"
    ].iloc[0]

    stvm_before = stvm_df.loc[
        (stvm_df["TimeGroup"] == before_group)
        & (stvm_df["New_Measurement"] == incident_measurement),
        "STVM"
    ].iloc[0]

    stvm_after = stvm_df.loc[
        (stvm_df["TimeGroup"] == after_group)
        & (stvm_df["New_Measurement"] == incident_measurement),
        "STVM"
    ].iloc[0]

    log_dc_df = pd.DataFrame({
        "Dc": dc,
        "log_Dc": np.log(dc),
        "EL": el,
        "S_before": s_before,
        "HV": hv,
        "Delta_STVM": stvm_after - stvm_before,
    }, index=[0])

    return log_dc_df


def centralization_log_d(df):
    df = df.copy()

    means = df[["EL", "Delta_STVM", "S_before", "HV"]].mean(numeric_only=True)

    df["EL_c"] = df["EL"] - means["EL"]
    df["S_c"] = df["S_before"] - means["S_before"]
    df["S_c**2"] = df["S_c"] ** 2
    df["HV_c"] = df["HV"] - means["HV"]
    df["Delta_STVM_c"] = df["Delta_STVM"] - means["Delta_STVM"]
    df["EL_c*S_c"] = df["EL_c"] * df["S_c"]

    result_df = df[[
        "Dc", "log_Dc", "EL_c", "S_c", "S_c**2", "HV_c", "Delta_STVM_c", "EL_c*S_c"
    ]]

    result_df = result_df.round(3)
    return result_df


def save_to_excel(excel_df, folder_path, file_name, color=False):
    result_folder = os.path.join(folder_path, "해상도+모형식 수정_260728")
    os.makedirs(result_folder, exist_ok=True)

    excel_file_name = f"{file_name}.xlsx"
    excel_file_path = os.path.join(result_folder, excel_file_name)

    if color:
        styled = excel_df.style.applymap(excel_color)
        styled.to_excel(excel_file_path, engine="openpyxl")
    else:
        excel_df.to_excel(excel_file_path, index=True)

    print(f"{excel_file_name} 생성 완료")


def excel_color(val):
    if pd.isna(val):
        return ""
    elif val <= 0:
        return "background-color: #FF0000"
    else:
        return "background-color: #FFC000"


# =============================================================================
# 6. 실행부
# =============================================================================
if __name__ == "__main__":
    senario_df = pd.read_csv(senario_path, encoding="cp949")

    tree = ET.parse(inpx_path)
    root = tree.getroot()

    for dcp in root.findall(".//dataCollectionPoint"):
        detector_no = int(dcp.get("no")) % 1000
        detector_link = int(dcp.get("lane").split()[0])
        detector_map[detector_no] = detector_link

    folder_path = path
    parquet_list = sorted([
        file for file in os.listdir(folder_path)
        if file.endswith(".parquet") and not file.startswith("processed_")
    ])

    processed_folder = os.path.join(folder_path, "processed")

    for sec_time_value in sec_time_list:
        sec_time = sec_time_value
        revision_time = 3600 / sec_time

        print(f"\n==============================")
        print(f"집계시간 {sec_time}초 processed 파일 생성/확인")
        print(f"==============================")

        build_processed_files(
            folder_path=folder_path,
            parquet_list=parquet_list,
            processed_folder=processed_folder,
            overwrite=False
        )

        for up_dcp_pos_value in up_dcp_pos_list:
            up_dcp_pos = up_dcp_pos_value

            print(f"\n===== 집계시간 {sec_time}초 / 상류검지기 {up_dcp_pos} =====")

            for continuous_num in continuous_list:
                continuous_n = int(continuous_num / sec_time)

                log_d_df_list = []
                gradient_list = []

                for idx, start in enumerate(range(0, len(parquet_list), num_mer)):
                    print(f"============ idx={idx}, start={start} ============")

                    row = senario_df.iloc[idx]

                    lane = row["lane_count"]
                    acc_lane = row["lane_closure_count"]
                    acc_finish_time = acc_start_time + row["incident_duration_min"] * 60

                    incident_location = row["location_name"]
                    locations = [x.strip() for x in incident_location.split(",")]
                    location = locations[0]

                    incident_measurement, lane_gradient = get_upstream_detector(root, location)
                    gradient_list.append((incident_measurement, lane_gradient))

                    batch_files = parquet_list[start:start + num_mer]

                    print("Vc:", Vc)
                    print(
                        f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] "
                        f"입력값 | 교통량={row['base_main_in_vph']}, "
                        f"기존 차로수={lane}, 유고 차로수={acc_lane}, "
                        f"유고지속시간={row['incident_duration_min']}, "
                        f"유고지점={incident_location}, 검지기={incident_measurement}, "
                        f"lane_gradient={lane_gradient}"
                    )

                    speed_list = []
                    density_list = []
                    heavy_list = []
                    entry_list = []
                    rfr_list_all = []
                    normality_list_all = []
                    stvm_list = []

                    for mer_file in batch_files:
                        processed_name = f"processed_{sec_time}sec_{mer_file}"
                        processed_path = os.path.join(processed_folder, processed_name)

                        print("processed 읽기:", processed_name)

                        processed_df = pd.read_parquet(processed_path)

                        speed_list.append(
                            processed_df[[
                                "StartTime", "EndTime", "TimeGroup", "New_Measurement",
                                "V_mean", "V_count", "delta_V"
                            ]]
                        )

                        density_list.append(
                            processed_df[[
                                "StartTime", "TimeGroup", "New_Measurement", "delta_K"
                            ]]
                        )

                        heavy_list.append(
                            processed_df[[
                                "StartTime", "TimeGroup", "New_Measurement", "rate"
                            ]]
                        )

                        entry_list.append(
                            processed_df[[
                                "StartTime", "TimeGroup", "New_Measurement", "Phi_진입"
                            ]]
                        )

                        rfr_list_all.append(
                            processed_df[[
                                "StartTime", "TimeGroup", "New_Measurement", "RFR"
                            ]]
                        )

                        normality_list_all.append(
                            processed_df[[
                                "StartTime", "TimeGroup", "New_Measurement", "F(outrate)"
                            ]]
                        )

                        stvm_list.append(
                            processed_df[[
                                "StartTime", "EndTime", "TimeGroup", "New_Measurement", "STVM"
                            ]]
                        )

                        del processed_df
                        gc.collect()

                    print("시드 평균 계산 중...")

                    merged_speed = pd.concat(speed_list, ignore_index=True)
                    merged_density = pd.concat(density_list, ignore_index=True)
                    merged_heavy = pd.concat(heavy_list, ignore_index=True)
                    merged_entry = pd.concat(entry_list, ignore_index=True)
                    merged_rfr = pd.concat(rfr_list_all, ignore_index=True)
                    merged_normality = pd.concat(normality_list_all, ignore_index=True)
                    merged_stvm = pd.concat(stvm_list, ignore_index=True)

                    speed_avg = (
                        merged_speed
                        .groupby(["StartTime", "EndTime", "TimeGroup", "New_Measurement"])
                        [["V_mean", "delta_V"]]
                        .mean()
                        .reset_index()
                    )

                    density_avg = (
                        merged_density
                        .groupby(["StartTime", "TimeGroup", "New_Measurement"])
                        [["delta_K"]]
                        .mean()
                        .reset_index()
                    )

                    heavy_avg = (
                        merged_heavy
                        .groupby(["StartTime", "TimeGroup", "New_Measurement"])
                        [["rate"]]
                        .mean()
                        .reset_index()
                    )

                    entry_avg = (
                        merged_entry
                        .groupby(["StartTime", "TimeGroup", "New_Measurement"])
                        [["Phi_진입"]]
                        .mean()
                        .reset_index()
                    )

                    rfr_avg = (
                        merged_rfr
                        .groupby(["StartTime", "TimeGroup", "New_Measurement"])
                        [["RFR"]]
                        .mean()
                        .reset_index()
                    )

                    normality_avg = (
                        merged_normality
                        .groupby(["StartTime", "TimeGroup", "New_Measurement"])
                        [["F(outrate)"]]
                        .mean()
                        .reset_index()
                    )

                    stvm_avg = (
                        merged_stvm
                        .groupby(["TimeGroup", "New_Measurement"], sort=False)
                        .mean(numeric_only=True)
                        .reset_index()
                    )

                    log_d_df = calculate_logD(speed_avg, entry_avg, heavy_avg, stvm_avg)
                    log_d_df_list.append(log_d_df)

                    del speed_list, density_list, heavy_list, entry_list, rfr_list_all, normality_list_all, stvm_list
                    del merged_speed, merged_density, merged_heavy, merged_entry, merged_rfr, merged_normality, merged_stvm
                    del speed_avg, density_avg, heavy_avg, entry_avg, rfr_avg, normality_avg, stvm_avg, log_d_df
                    gc.collect()

                log_d_df_all = pd.concat(log_d_df_list, ignore_index=True)
                final_log_d = centralization_log_d(log_d_df_all)
                final_log_d = final_log_d.fillna("NA")

                save_to_excel(
                    final_log_d,
                    folder_path,
                    f"임계연속시간_본선부_구간1_{sec_time}초_{150 + (up_dcp_pos - 1) * 100}m"
                )

                del log_d_df_list, log_d_df_all, final_log_d
                gc.collect()
# Out:
# ==============================
# 집계시간 10초 processed 파일 생성/확인
# ==============================
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_034.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_035.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_036.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_037.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_038.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_039.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_040.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_041.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_042.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_043.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_044.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_045.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_046.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_047.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_048.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_049.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_050.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_051.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_052.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_053.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_054.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_055.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_056.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_057.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_058.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_059.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_060.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_061.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 생성: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
#
# ===== 집계시간 10초 / 상류검지기 0 =====
# ============ idx=0, start=0 ============
# Vc: 53.7
# [2026-07-28 21:45:15] 입력값 | 교통량=1104, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부32-1, 검지기=61, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=1, start=3 ============
# Vc: 53.7
# [2026-07-28 21:45:17] 입력값 | 교통량=889, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부28-1,본선부28-2, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=2, start=6 ============
# Vc: 53.7
# [2026-07-28 21:45:19] 입력값 | 교통량=654, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부12-1, 검지기=41, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=3, start=9 ============
# Vc: 53.7
# [2026-07-28 21:45:21] 입력값 | 교통량=1280, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부9-1,본선부9-2, 검지기=38, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=4, start=12 ============
# Vc: 53.7
# [2026-07-28 21:45:22] 입력값 | 교통량=786, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=5, start=15 ============
# Vc: 53.7
# [2026-07-28 21:45:24] 입력값 | 교통량=1429, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부18-1,본선부18-2, 검지기=47, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=6, start=18 ============
# Vc: 53.7
# [2026-07-28 21:45:26] 입력값 | 교통량=702, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부37-1, 검지기=66, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=7, start=21 ============
# Vc: 53.7
# [2026-07-28 21:45:28] 입력값 | 교통량=1635, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부31-1, 검지기=60, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# 시드 평균 계산 중...
# dc: 4.333333333333333
# ============ idx=8, start=24 ============
# Vc: 53.7
# [2026-07-28 21:45:30] 입력값 | 교통량=665, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부38-1, 검지기=67, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=9, start=27 ============
# Vc: 53.7
# [2026-07-28 21:45:33] 입력값 | 교통량=2219, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부27-1, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# 시드 평균 계산 중...
# dc: 3.8333333333333335
# ============ idx=10, start=30 ============
# Vc: 53.7
# [2026-07-28 21:45:35] 입력값 | 교통량=2845, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부29-1, 검지기=58, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=11, start=33 ============
# Vc: 53.7
# [2026-07-28 21:45:38] 입력값 | 교통량=1952, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_034.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_035.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_036.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=12, start=36 ============
# Vc: 53.7
# [2026-07-28 21:45:40] 입력값 | 교통량=2264, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부18-1, 검지기=47, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_037.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_038.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_039.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=13, start=39 ============
# Vc: 53.7
# [2026-07-28 21:45:42] 입력값 | 교통량=2642, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부2-1, 검지기=31, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_040.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_041.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_042.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=14, start=42 ============
# Vc: 53.7
# [2026-07-28 21:45:44] 입력값 | 교통량=2894, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부28-1, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_043.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_044.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_045.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=15, start=45 ============
# Vc: 53.7
# [2026-07-28 21:45:47] 입력값 | 교통량=2255, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부34-1,본선부34-2, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_046.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_047.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_048.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=16, start=48 ============
# Vc: 53.7
# [2026-07-28 21:45:49] 입력값 | 교통량=2013, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=69, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_049.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_050.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_051.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=17, start=51 ============
# Vc: 53.7
# [2026-07-28 21:45:52] 입력값 | 교통량=2616, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부35-1,본선부35-2, 검지기=64, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_052.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_053.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_054.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=18, start=54 ============
# Vc: 53.7
# [2026-07-28 21:45:54] 입력값 | 교통량=3623, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부7-1,본선부7-2, 검지기=36, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_055.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_056.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_057.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=19, start=57 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:45:56] 입력값 | 교통량=3568, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=30, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_058.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_059.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_060.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=20, start=60 ============
# Vc: 53.7
# [2026-07-28 21:45:58] 입력값 | 교통량=3408, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부37-1,본선부37-2, 검지기=66, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_061.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=21, start=63 ============
# Vc: 53.7
# [2026-07-28 21:46:00] 입력값 | 교통량=3380, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부18-1, 검지기=47, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=22, start=66 ============
# Vc: 53.7
# [2026-07-28 21:46:02] 입력값 | 교통량=3522, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부22-1, 검지기=51, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=23, start=69 ============
# Vc: 53.7
# [2026-07-28 21:46:04] 입력값 | 교통량=3340, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부28-1, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=24, start=72 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:46:06] 입력값 | 교통량=3672, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=30, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=25, start=75 ============
# Vc: 53.7
# [2026-07-28 21:46:08] 입력값 | 교통량=3806, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부26-1,본선부26-2, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=26, start=78 ============
# Vc: 53.7
# [2026-07-28 21:46:10] 입력값 | 교통량=3823, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=69, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=27, start=81 ============
# Vc: 53.7
# [2026-07-28 21:46:12] 입력값 | 교통량=3802, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부8-1,본선부8-2, 검지기=37, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# 시드 평균 계산 중...
# dc: 3.0
# ============ idx=28, start=84 ============
# Vc: 53.7
# [2026-07-28 21:46:15] 입력값 | 교통량=3508, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부10-1, 검지기=39, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=29, start=87 ============
# Vc: 53.7
# [2026-07-28 21:46:17] 입력값 | 교통량=3517, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부34-1, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# 임계연속시간_본선부_구간1_10초_50m.xlsx 생성 완료
#
# ===== 집계시간 10초 / 상류검지기 1 =====
# ============ idx=0, start=0 ============
# Vc: 53.7
# [2026-07-28 21:46:19] 입력값 | 교통량=1104, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부32-1, 검지기=60, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=1, start=3 ============
# Vc: 53.7
# [2026-07-28 21:46:21] 입력값 | 교통량=889, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부28-1,본선부28-2, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# 시드 평균 계산 중...
# dc: 4.666666666666667
# ============ idx=2, start=6 ============
# Vc: 53.7
# [2026-07-28 21:46:24] 입력값 | 교통량=654, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부12-1, 검지기=40, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=3, start=9 ============
# Vc: 53.7
# [2026-07-28 21:46:26] 입력값 | 교통량=1280, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부9-1,본선부9-2, 검지기=37, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=4, start=12 ============
# Vc: 53.7
# [2026-07-28 21:46:29] 입력값 | 교통량=786, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=5, start=15 ============
# Vc: 53.7
# [2026-07-28 21:46:31] 입력값 | 교통량=1429, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부18-1,본선부18-2, 검지기=46, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# 시드 평균 계산 중...
# dc: 4.166666666666667
# ============ idx=6, start=18 ============
# Vc: 53.7
# [2026-07-28 21:46:33] 입력값 | 교통량=702, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부37-1, 검지기=65, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=7, start=21 ============
# Vc: 53.7
# [2026-07-28 21:46:35] 입력값 | 교통량=1635, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부31-1, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# 시드 평균 계산 중...
# dc: 20.5
# ============ idx=8, start=24 ============
# Vc: 53.7
# [2026-07-28 21:46:37] 입력값 | 교통량=665, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부38-1, 검지기=66, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=9, start=27 ============
# Vc: 53.7
# [2026-07-28 21:46:39] 입력값 | 교통량=2219, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부27-1, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=10, start=30 ============
# Vc: 53.7
# [2026-07-28 21:46:41] 입력값 | 교통량=2845, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부29-1, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=11, start=33 ============
# Vc: 53.7
# [2026-07-28 21:46:44] 입력값 | 교통량=1952, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_034.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_035.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_036.parquet
# 시드 평균 계산 중...
# dc: 5.833333333333333
# ============ idx=12, start=36 ============
# Vc: 53.7
# [2026-07-28 21:46:46] 입력값 | 교통량=2264, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부18-1, 검지기=46, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_037.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_038.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_039.parquet
# 시드 평균 계산 중...
# dc: 5.833333333333333
# ============ idx=13, start=39 ============
# Vc: 53.7
# [2026-07-28 21:46:48] 입력값 | 교통량=2642, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부2-1, 검지기=30, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_040.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_041.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_042.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=14, start=42 ============
# Vc: 53.7
# [2026-07-28 21:46:51] 입력값 | 교통량=2894, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부28-1, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_043.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_044.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_045.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=15, start=45 ============
# Vc: 53.7
# [2026-07-28 21:46:53] 입력값 | 교통량=2255, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부34-1,본선부34-2, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_046.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_047.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_048.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=16, start=48 ============
# Vc: 53.7
# [2026-07-28 21:46:56] 입력값 | 교통량=2013, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=68, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_049.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_050.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_051.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=17, start=51 ============
# Vc: 53.7
# [2026-07-28 21:46:58] 입력값 | 교통량=2616, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부35-1,본선부35-2, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_052.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_053.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_054.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=18, start=54 ============
# Vc: 53.7
# [2026-07-28 21:47:00] 입력값 | 교통량=3623, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부7-1,본선부7-2, 검지기=35, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_055.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_056.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_057.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=19, start=57 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:47:03] 입력값 | 교통량=3568, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=29, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_058.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_059.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_060.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=20, start=60 ============
# Vc: 53.7
# [2026-07-28 21:47:06] 입력값 | 교통량=3408, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부37-1,본선부37-2, 검지기=65, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_061.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# 시드 평균 계산 중...
# dc: 3.1666666666666665
# ============ idx=21, start=63 ============
# Vc: 53.7
# [2026-07-28 21:47:08] 입력값 | 교통량=3380, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부18-1, 검지기=46, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=22, start=66 ============
# Vc: 53.7
# [2026-07-28 21:47:11] 입력값 | 교통량=3522, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부22-1, 검지기=50, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=23, start=69 ============
# Vc: 53.7
# [2026-07-28 21:47:13] 입력값 | 교통량=3340, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부28-1, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=24, start=72 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:47:15] 입력값 | 교통량=3672, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=29, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=25, start=75 ============
# Vc: 53.7
# [2026-07-28 21:47:17] 입력값 | 교통량=3806, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부26-1,본선부26-2, 검지기=54, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=26, start=78 ============
# Vc: 53.7
# [2026-07-28 21:47:19] 입력값 | 교통량=3823, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=68, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# 시드 평균 계산 중...
# dc: 3.3333333333333335
# ============ idx=27, start=81 ============
# Vc: 53.7
# [2026-07-28 21:47:22] 입력값 | 교통량=3802, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부8-1,본선부8-2, 검지기=36, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=28, start=84 ============
# Vc: 53.7
# [2026-07-28 21:47:24] 입력값 | 교통량=3508, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부10-1, 검지기=38, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# 시드 평균 계산 중...
# dc: 3.8333333333333335
# ============ idx=29, start=87 ============
# Vc: 53.7
# [2026-07-28 21:47:27] 입력값 | 교통량=3517, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부34-1, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
# 시드 평균 계산 중...
# dc: 3.5
# 임계연속시간_본선부_구간1_10초_150m.xlsx 생성 완료
#
# ===== 집계시간 10초 / 상류검지기 2 =====
# ============ idx=0, start=0 ============
# Vc: 53.7
# [2026-07-28 21:47:29] 입력값 | 교통량=1104, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부32-1, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=1, start=3 ============
# Vc: 53.7
# [2026-07-28 21:47:31] 입력값 | 교통량=889, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부28-1,본선부28-2, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# 시드 평균 계산 중...
# dc: 6.333333333333333
# ============ idx=2, start=6 ============
# Vc: 53.7
# [2026-07-28 21:47:34] 입력값 | 교통량=654, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부12-1, 검지기=39, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=3, start=9 ============
# Vc: 53.7
# [2026-07-28 21:47:36] 입력값 | 교통량=1280, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부9-1,본선부9-2, 검지기=36, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=4, start=12 ============
# Vc: 53.7
# [2026-07-28 21:47:38] 입력값 | 교통량=786, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=61, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=5, start=15 ============
# Vc: 53.7
# [2026-07-28 21:47:41] 입력값 | 교통량=1429, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부18-1,본선부18-2, 검지기=45, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# 시드 평균 계산 중...
# dc: 5.333333333333333
# ============ idx=6, start=18 ============
# Vc: 53.7
# [2026-07-28 21:47:43] 입력값 | 교통량=702, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부37-1, 검지기=64, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=7, start=21 ============
# Vc: 53.7
# [2026-07-28 21:47:46] 입력값 | 교통량=1635, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부31-1, 검지기=58, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=8, start=24 ============
# Vc: 53.7
# [2026-07-28 21:47:48] 입력값 | 교통량=665, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부38-1, 검지기=65, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=9, start=27 ============
# Vc: 53.7
# [2026-07-28 21:47:51] 입력값 | 교통량=2219, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부27-1, 검지기=54, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=10, start=30 ============
# Vc: 53.7
# [2026-07-28 21:47:53] 입력값 | 교통량=2845, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부29-1, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# 시드 평균 계산 중...
# dc: 4.833333333333333
# ============ idx=11, start=33 ============
# Vc: 53.7
# [2026-07-28 21:47:56] 입력값 | 교통량=1952, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=61, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_034.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_035.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_036.parquet
# 시드 평균 계산 중...
# dc: 9.833333333333334
# ============ idx=12, start=36 ============
# Vc: 53.7
# [2026-07-28 21:47:58] 입력값 | 교통량=2264, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부18-1, 검지기=45, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_037.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_038.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_039.parquet
# 시드 평균 계산 중...
# dc: 6.666666666666667
# ============ idx=13, start=39 ============
# Vc: 53.7
# [2026-07-28 21:48:00] 입력값 | 교통량=2642, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부2-1, 검지기=29, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_040.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_041.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_042.parquet
# 시드 평균 계산 중...
# dc: 4.333333333333333
# ============ idx=14, start=42 ============
# Vc: 53.7
# [2026-07-28 21:48:02] 입력값 | 교통량=2894, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부28-1, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_043.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_044.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_045.parquet
# 시드 평균 계산 중...
# dc: 4.166666666666667
# ============ idx=15, start=45 ============
# Vc: 53.7
# [2026-07-28 21:48:04] 입력값 | 교통량=2255, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부34-1,본선부34-2, 검지기=61, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_046.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_047.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_048.parquet
# 시드 평균 계산 중...
# dc: 4.333333333333333
# ============ idx=16, start=48 ============
# Vc: 53.7
# [2026-07-28 21:48:06] 입력값 | 교통량=2013, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=67, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_049.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_050.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_051.parquet
# 시드 평균 계산 중...
# dc: 4.833333333333333
# ============ idx=17, start=51 ============
# Vc: 53.7
# [2026-07-28 21:48:09] 입력값 | 교통량=2616, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부35-1,본선부35-2, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_052.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_053.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_054.parquet
# 시드 평균 계산 중...
# dc: 4.333333333333333
# ============ idx=18, start=54 ============
# Vc: 53.7
# [2026-07-28 21:48:11] 입력값 | 교통량=3623, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부7-1,본선부7-2, 검지기=34, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_055.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_056.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_057.parquet
# 시드 평균 계산 중...
# dc: 3.8333333333333335
# ============ idx=19, start=57 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:48:13] 입력값 | 교통량=3568, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=28, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_058.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_059.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_060.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=20, start=60 ============
# Vc: 53.7
# [2026-07-28 21:48:16] 입력값 | 교통량=3408, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부37-1,본선부37-2, 검지기=64, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_061.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=21, start=63 ============
# Vc: 53.7
# [2026-07-28 21:48:18] 입력값 | 교통량=3380, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부18-1, 검지기=45, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# 시드 평균 계산 중...
# dc: 3.8333333333333335
# ============ idx=22, start=66 ============
# Vc: 53.7
# [2026-07-28 21:48:20] 입력값 | 교통량=3522, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부22-1, 검지기=49, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=23, start=69 ============
# Vc: 53.7
# [2026-07-28 21:48:23] 입력값 | 교통량=3340, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부28-1, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# 시드 평균 계산 중...
# dc: 4.166666666666667
# ============ idx=24, start=72 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 21:48:25] 입력값 | 교통량=3672, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=28, lane_gradient=-0.0399
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=25, start=75 ============
# Vc: 53.7
# [2026-07-28 21:48:28] 입력값 | 교통량=3806, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부26-1,본선부26-2, 검지기=53, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=26, start=78 ============
# Vc: 53.7
# [2026-07-28 21:48:30] 입력값 | 교통량=3823, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=67, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# 시드 평균 계산 중...
# dc: 3.6666666666666665
# ============ idx=27, start=81 ============
# Vc: 53.7
# [2026-07-28 21:48:33] 입력값 | 교통량=3802, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부8-1,본선부8-2, 검지기=35, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# 시드 평균 계산 중...
# dc: 3.8333333333333335
# ============ idx=28, start=84 ============
# Vc: 53.7
# [2026-07-28 21:48:36] 입력값 | 교통량=3508, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부10-1, 검지기=37, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# 시드 평균 계산 중...
# dc: 4.166666666666667
# ============ idx=29, start=87 ============
# Vc: 53.7
# [2026-07-28 21:48:39] 입력값 | 교통량=3517, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부34-1, 검지기=61, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
# 시드 평균 계산 중...
# dc: 4.166666666666667
# 임계연속시간_본선부_구간1_10초_250m.xlsx 생성 완료
#
# ===== 집계시간 10초 / 상류검지기 3 =====
# ============ idx=0, start=0 ============
# Vc: 53.7
# [2026-07-28 21:48:41] 입력값 | 교통량=1104, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부32-1, 검지기=58, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=1, start=3 ============
# Vc: 53.7
# [2026-07-28 21:48:44] 입력값 | 교통량=889, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부28-1,본선부28-2, 검지기=54, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# 시드 평균 계산 중...
# dc: 7.833333333333333
# ============ idx=2, start=6 ============
# Vc: 53.7
# [2026-07-28 21:48:46] 입력값 | 교통량=654, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부12-1, 검지기=38, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=3, start=9 ============
# Vc: 53.7
# [2026-07-28 21:48:49] 입력값 | 교통량=1280, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부9-1,본선부9-2, 검지기=35, lane_gradient=0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=4, start=12 ============
# Vc: 53.7
# [2026-07-28 21:48:52] 입력값 | 교통량=786, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=60, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=5, start=15 ============
# Vc: 53.7
# [2026-07-28 21:48:55] 입력값 | 교통량=1429, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부18-1,본선부18-2, 검지기=44, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# 시드 평균 계산 중...
# dc: 6.166666666666667
# ============ idx=6, start=18 ============
# Vc: 53.7
# [2026-07-28 21:48:57] 입력값 | 교통량=702, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부37-1, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=7, start=21 ============
# Vc: 53.7
# [2026-07-28 21:49:00] 입력값 | 교통량=1635, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부31-1, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=8, start=24 ============
# Vc: 53.7
# [2026-07-28 21:49:03] 입력값 | 교통량=665, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부38-1, 검지기=64, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=9, start=27 ============
# Vc: 53.7
# [2026-07-28 21:49:06] 입력값 | 교통량=2219, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부27-1, 검지기=53, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=10, start=30 ============
# Vc: 53.7
# [2026-07-28 21:49:09] 입력값 | 교통량=2845, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부29-1, 검지기=55, lane_gradient=-0.005
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 읽기: processed_10sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# 시드 평균 계산 중...
# dc: 5.166666666666667
# ...
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=21, start=63 ============
# Vc: 53.7
# [2026-07-28 22:36:27] 입력값 | 교통량=3380, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부18-1, 검지기=44, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=22, start=66 ============
# Vc: 53.7
# [2026-07-28 22:36:28] 입력값 | 교통량=3522, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부22-1, 검지기=48, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=23, start=69 ============
# Vc: 53.7
# [2026-07-28 22:36:28] 입력값 | 교통량=3340, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부28-1, 검지기=54, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=24, start=72 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 22:36:29] 입력값 | 교통량=3672, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=27, lane_gradient=-0.0399
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=25, start=75 ============
# Vc: 53.7
# [2026-07-28 22:36:30] 입력값 | 교통량=3806, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부26-1,본선부26-2, 검지기=52, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# 시드 평균 계산 중...
# dc: 3.5
# ============ idx=26, start=78 ============
# Vc: 53.7
# [2026-07-28 22:36:31] 입력값 | 교통량=3823, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=66, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=27, start=81 ============
# Vc: 53.7
# [2026-07-28 22:36:31] 입력값 | 교통량=3802, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부8-1,본선부8-2, 검지기=34, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=28, start=84 ============
# Vc: 53.7
# [2026-07-28 22:36:32] 입력값 | 교통량=3508, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부10-1, 검지기=36, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=29, start=87 ============
# Vc: 53.7
# [2026-07-28 22:36:33] 입력값 | 교통량=3517, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부34-1, 검지기=60, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
# 시드 평균 계산 중...
# dc: 4.5
# 임계연속시간_본선부_구간1_30초_350m.xlsx 생성 완료
#
# ===== 집계시간 30초 / 상류검지기 4 =====
# ============ idx=0, start=0 ============
# Vc: 53.7
# [2026-07-28 22:36:34] 입력값 | 교통량=1104, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부32-1, 검지기=57, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_001.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_002.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_003.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=1, start=3 ============
# Vc: 53.7
# [2026-07-28 22:36:34] 입력값 | 교통량=889, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부28-1,본선부28-2, 검지기=53, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_004.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_005.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_006.parquet
# 시드 평균 계산 중...
# dc: 10.0
# ============ idx=2, start=6 ============
# Vc: 53.7
# [2026-07-28 22:36:35] 입력값 | 교통량=654, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부12-1, 검지기=37, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_007.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_008.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_009.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=3, start=9 ============
# Vc: 53.7
# [2026-07-28 22:36:36] 입력값 | 교통량=1280, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부9-1,본선부9-2, 검지기=34, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_010.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_011.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_012.parquet
# 시드 평균 계산 중...
# dc: 7.0
# ============ idx=4, start=12 ============
# Vc: 53.7
# [2026-07-28 22:36:36] 입력값 | 교통량=786, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_013.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_014.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_015.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=5, start=15 ============
# Vc: 53.7
# [2026-07-28 22:36:37] 입력값 | 교통량=1429, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부18-1,본선부18-2, 검지기=43, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_016.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_017.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_018.parquet
# 시드 평균 계산 중...
# dc: 7.5
# ============ idx=6, start=18 ============
# Vc: 53.7
# [2026-07-28 22:36:38] 입력값 | 교통량=702, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부37-1, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_019.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_020.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_021.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=7, start=21 ============
# Vc: 53.7
# [2026-07-28 22:36:38] 입력값 | 교통량=1635, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부31-1, 검지기=56, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_022.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_023.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_024.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=8, start=24 ============
# Vc: 53.7
# [2026-07-28 22:36:39] 입력값 | 교통량=665, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부38-1, 검지기=63, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_025.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_026.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_027.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=9, start=27 ============
# Vc: 53.7
# [2026-07-28 22:36:40] 입력값 | 교통량=2219, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부27-1, 검지기=52, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_028.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_029.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_030.parquet
# 시드 평균 계산 중...
# dc: nan
# ============ idx=10, start=30 ============
# Vc: 53.7
# [2026-07-28 22:36:41] 입력값 | 교통량=2845, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부29-1, 검지기=54, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_031.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_032.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_033.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=11, start=33 ============
# Vc: 53.7
# [2026-07-28 22:36:41] 입력값 | 교통량=1952, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부34-1, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_034.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_035.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_036.parquet
# 시드 평균 계산 중...
# dc: 18.5
# ============ idx=12, start=36 ============
# Vc: 53.7
# [2026-07-28 22:36:42] 입력값 | 교통량=2264, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부18-1, 검지기=43, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_037.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_038.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_039.parquet
# 시드 평균 계산 중...
# dc: 8.5
# ============ idx=13, start=39 ============
# Vc: 53.7
# [2026-07-28 22:36:43] 입력값 | 교통량=2642, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부2-1, 검지기=27, lane_gradient=-0.0399
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_040.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_041.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_042.parquet
# 시드 평균 계산 중...
# dc: 5.5
# ============ idx=14, start=42 ============
# Vc: 53.7
# [2026-07-28 22:36:43] 입력값 | 교통량=2894, 기존 차로수=2, 유고 차로수=1, 유고지속시간=30, 유고지점=본선부28-1, 검지기=53, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_043.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_044.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_045.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=15, start=45 ============
# Vc: 53.7
# [2026-07-28 22:36:44] 입력값 | 교통량=2255, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부34-1,본선부34-2, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_046.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_047.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_048.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=16, start=48 ============
# Vc: 53.7
# [2026-07-28 22:36:45] 입력값 | 교통량=2013, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=65, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_049.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_050.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_051.parquet
# 시드 평균 계산 중...
# dc: 6.0
# ============ idx=17, start=51 ============
# Vc: 53.7
# [2026-07-28 22:36:46] 입력값 | 교통량=2616, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부35-1,본선부35-2, 검지기=60, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_052.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_053.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_054.parquet
# 시드 평균 계산 중...
# dc: 5.5
# ============ idx=18, start=54 ============
# Vc: 53.7
# [2026-07-28 22:36:47] 입력값 | 교통량=3623, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부7-1,본선부7-2, 검지기=32, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_055.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_056.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_057.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=19, start=57 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 22:36:47] 입력값 | 교통량=3568, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=26, lane_gradient=-0.0399
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_058.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_059.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_060.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=20, start=60 ============
# Vc: 53.7
# [2026-07-28 22:36:48] 입력값 | 교통량=3408, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부37-1,본선부37-2, 검지기=62, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_061.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_062.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_063.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=21, start=63 ============
# Vc: 53.7
# [2026-07-28 22:36:48] 입력값 | 교통량=3380, 기존 차로수=2, 유고 차로수=1, 유고지속시간=5, 유고지점=본선부18-1, 검지기=43, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_064.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_065.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_066.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=22, start=66 ============
# Vc: 53.7
# [2026-07-28 22:36:49] 입력값 | 교통량=3522, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부22-1, 검지기=47, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_067.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_068.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_069.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=23, start=69 ============
# Vc: 53.7
# [2026-07-28 22:36:50] 입력값 | 교통량=3340, 기존 차로수=2, 유고 차로수=1, 유고지속시간=10, 유고지점=본선부28-1, 검지기=53, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_070.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_071.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_072.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=24, start=72 ============
# 링크 번호가 다름
# Vc: 53.7
# [2026-07-28 22:36:50] 입력값 | 교통량=3672, 기존 차로수=2, 유고 차로수=1, 유고지속시간=20, 유고지점=본선부1-1, 검지기=26, lane_gradient=-0.0399
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_073.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_074.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_075.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=25, start=75 ============
# Vc: 53.7
# [2026-07-28 22:36:51] 입력값 | 교통량=3806, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부26-1,본선부26-2, 검지기=51, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_076.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_077.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_078.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=26, start=78 ============
# Vc: 53.7
# [2026-07-28 22:36:52] 입력값 | 교통량=3823, 기존 차로수=2, 유고 차로수=2, 유고지속시간=60, 유고지점=본선부40-1,본선부40-2, 검지기=65, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_079.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_080.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_081.parquet
# 시드 평균 계산 중...
# dc: 4.0
# ============ idx=27, start=81 ============
# Vc: 53.7
# [2026-07-28 22:36:52] 입력값 | 교통량=3802, 기존 차로수=2, 유고 차로수=2, 유고지속시간=50, 유고지점=본선부8-1,본선부8-2, 검지기=33, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_082.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_083.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_084.parquet
# 시드 평균 계산 중...
# dc: 4.5
# ============ idx=28, start=84 ============
# Vc: 53.7
# [2026-07-28 22:36:53] 입력값 | 교통량=3508, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부10-1, 검지기=35, lane_gradient=0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_085.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_086.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_087.parquet
# 시드 평균 계산 중...
# dc: 5.0
# ============ idx=29, start=87 ============
# Vc: 53.7
# [2026-07-28 22:36:53] 입력값 | 교통량=3517, 기존 차로수=2, 유고 차로수=1, 유고지속시간=60, 유고지점=본선부34-1, 검지기=59, lane_gradient=-0.005
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_088.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_089.parquet
# processed 읽기: processed_30sec_화성~서울(30-본선부_구간1-검증용)_260615_090.parquet
# 시드 평균 계산 중...
# dc: 5.0
# 임계연속시간_본선부_구간1_30초_450m.xlsx 생성 완료
