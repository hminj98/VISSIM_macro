# %%
"""output(결과) 파일에서 데이터 가공 (교통량, 지체시간)"""

import pandas as pd
import os
"""output 파일 양식 수정"""
output_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350" # 결과엑셀 파일이 있는 폴더경로까지
output_files = sorted([f for f in os.listdir(output_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("output_files : ", output_files)
mer_list = []
for i in range(len(output_files)):
    work_file = os.path.join(output_path, output_files[i])
    print(f"{work_file} 작업중...")
    df = pd.read_excel(work_file)

    # 신규 그룹 컬럼 생성
    df["NEW"] = df["DATACOLLECTIONMEASUREMENT"] % 1000

    # 기존 DATACOLLECTIONMEASUREMENT 컬럼의 값이 같은 것끼리 평균 계산
    df_grouped = df.groupby("DATACOLLECTIONMEASUREMENT").mean()

    # VEHS(ALL), QUEUEDELAY(ALL) 컬럼의 값만 합 연산, 나머지는 평균
    df_newGrouped = df_grouped.groupby("NEW").agg(lambda x: x.sum() if x.name == "VEHS(ALL)" or x.name == "QUEUEDELAY(ALL)" else x.mean()).reset_index()

    df_newGrouped["VEHS(ALL)"] = df_newGrouped["VEHS(ALL)"] * 60
    df = df_newGrouped[["NEW", "VEHS(ALL)", "QUEUEDELAY(ALL)"]]
    del df_newGrouped

    # 진입부
    start_df = df[(df["NEW"] >= 1) & (df["NEW"] <=20)]
    # 본선부
    mid_df = df[(df["NEW"] >= 21) & (df["NEW"] <=100)]
    # 진출부
    end_df = df[(df["NEW"] >= 101) & (df["NEW"] <=120)]
    # 전체
    total_df = df[(df["NEW"] >= 1) & (df["NEW"] <=120)]

    # 평균 계산 전 "NEW" 제거
    df1 = start_df.drop(columns=["NEW"]).sum().to_frame().T
    df2 = mid_df.drop(columns=["NEW"]).sum().to_frame().T
    df3 = end_df.drop(columns=["NEW"]).sum().to_frame().T
    df4 = total_df.drop(columns=["NEW"]).sum().to_frame().T

    # 다차원 배열을 1차원 배열로 변환 -> 인덱싱 유리
    df1_vals = df1.values.flatten()
    df2_vals = df2.values.flatten()
    df3_vals = df3.values.flatten()
    df4_vals = df4.values.flatten()

    # 컬럼 정의
    columns = [
        "파일명",
        "VEHS(ALL)_진입", "VEHS(ALL)_본선", "VEHS(ALL)_진출", "VEHS(ALL)_전체",
        "QUEUEDELAY(ALL)_진입", "QUEUEDELAY(ALL)_본선", "QUEUEDELAY(ALL)_진출", "QUEUEDELAY(ALL)_전체"
    ]
    # 컬럼 순서 정렬
    merged_data = [
        output_files[i],
        df1_vals[0], df2_vals[0], df3_vals[0], df4_vals[0],  # VEHS(ALL)_*
        df1_vals[1], df2_vals[1], df3_vals[1], df4_vals[1],  # QUEUEDELAY(ALL)_*
    ]

    merged_df = pd.DataFrame([merged_data], columns=columns)
    mer_list.append(merged_df)


final_df = pd.concat(mer_list, ignore_index=True).round(4)
display(final_df)

excel_path = os.path.join(output_path, "volume_output")
print("excel_path : ", excel_path)
if not os.path.exists(excel_path):
    os.makedirs(excel_path)
excel_file_path = os.path.join(excel_path, "volume_output.xlsx")
final_df.to_excel(excel_file_path, index=False)
print("작업이 완료 되었습니다.")
# Out:
# output_files :  ['1_output.xlsx', '2_output.xlsx', '3_output.xlsx', '4_output.xlsx', '5_output.xlsx', '6_output.xlsx', '7_output.xlsx', '8_output.xlsx', '9_output.xlsx', '10_output.xlsx', '11_output.xlsx', '12_output.xlsx', '13_output.xlsx', '14_output.xlsx', '15_output.xlsx', '16_output.xlsx', '17_output.xlsx', '18_output.xlsx', '19_output.xlsx', '20_output.xlsx', '21_output.xlsx', '22_output.xlsx', '23_output.xlsx', '24_output.xlsx']
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\1_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\2_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\3_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\4_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\5_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\6_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\7_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\8_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\9_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\10_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\11_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\12_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\13_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\14_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\15_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\16_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\17_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\18_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\19_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\20_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\21_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\22_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\23_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\24_output.xlsx 작업중...
#                파일명  VEHS(ALL)_진입  VEHS(ALL)_본선  VEHS(ALL)_진출  VEHS(ALL)_전체  \
# 0    1_output.xlsx       81141.2      325415.3       76972.2      483528.7
# 1    2_output.xlsx       81142.4      325409.2       77003.2      483554.8
# 2    3_output.xlsx       81142.6      325370.0       77022.9      483535.5
# 3    4_output.xlsx       81144.6      325362.8       77052.8      483560.2
# 4    5_output.xlsx       80521.5      322883.7       76492.1      479897.3
# 5    6_output.xlsx       80522.1      322923.7       76532.2      479978.0
# 6    7_output.xlsx       80520.8      322919.1       76519.7      479959.6
# 7    8_output.xlsx       80520.0      322888.2       76482.2      479890.4
# 8    9_output.xlsx       79852.1      320273.3       75852.0      475977.4
# 9   10_output.xlsx       79851.8      320288.6       75817.4      475957.8
# 10  11_output.xlsx       79853.2      320274.6       75827.5      475955.3
# 11  12_output.xlsx       79851.9      320285.4       75769.2      475906.5
# 12  13_output.xlsx       79261.5      317795.4       75276.6      472333.5
# 13  14_output.xlsx       79261.2      317824.0       75274.5      472359.7
# 14  15_output.xlsx       79259.5      317837.5       75233.4      472330.4
# 15  16_output.xlsx       79262.8      317757.4       75164.8      472185.0
# 16  17_output.xlsx       78668.4      315404.9       74602.7      468676.0
# 17  18_output.xlsx       78669.8      315315.6       74589.5      468574.9
# 18  19_output.xlsx       78673.7      315309.8       74588.0      468571.5
# 19  20_output.xlsx       78674.8      315420.8       74575.8      468671.4
# 20  21_output.xlsx       78119.6      312778.7       73931.0      464829.3
# 21  22_output.xlsx       78117.3      312758.5       73928.3      464804.1
# 22  23_output.xlsx       78117.7      312787.4       73951.7      464856.8
# 23  24_output.xlsx       78117.6      312793.0       74017.9      464928.5
#
#     QUEUEDELAY(ALL)_진입  QUEUEDELAY(ALL)_본선  QUEUEDELAY(ALL)_진출  \
# 0                  0.0                 0.0              0.0000
# 1                  0.0                 0.0              0.0000
# 2                  0.0                 0.0              0.0000
# 3                  0.0                 0.0              0.0948
# 4                  0.0                 0.0              0.0000
# 5                  0.0                 0.0              0.0000
# 6                  0.0                 0.0              0.0017
# 7                  0.0                 0.0              1.0595
# 8                  0.0                 0.0              0.0000
# 9                  0.0                 0.0              0.0000
# 10                 0.0                 0.0              0.0343
# 11                 0.0                 0.0              2.8195
# 12                 0.0                 0.0              0.0000
# 13                 0.0                 0.0              0.0000
# 14                 0.0                 0.0              0.1235
# 15                 0.0                 0.0              2.0995
# 16                 0.0                 0.0              0.0000
# 17                 0.0                 0.0              0.0243
# 18                 0.0                 0.0              0.1957
# 19                 0.0                 0.0              3.2498
# 20                 0.0                 0.0              0.0000
# 21                 0.0                 0.0              0.0028
# 22                 0.0                 0.0              0.1400
# 23                 0.0                 0.0              4.1880
#
#     QUEUEDELAY(ALL)_전체
# 0               0.0000
# 1               0.0000
# 2               0.0000
# 3               0.0948
# 4               0.0000
# 5               0.0000
# 6               0.0017
# 7               1.0595
# 8               0.0000
# 9               0.0000
# 10              0.0343
# 11              2.8195
# 12              0.0000
# 13              0.0000
# 14              0.1235
# 15              2.0995
# 16              0.0000
# 17              0.0243
# 18              0.1957
# 19              3.2498
# 20              0.0000
# 21              0.0028
# 22              0.1400
# 23              4.1880
# excel_path :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\시뮬레이션 분석 자료_V2.3\중차량,종단경사,교통량\결과파일\1350\volume_output
# 작업이 완료 되었습니다.
