# %%
"""output(결과) 파일에서 데이터 가공 (교통량, 지체시간)"""

import pandas as pd
import os
"""output 파일 양식 수정"""
output_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1750" # 결과엑셀 파일이 있는 폴더경로까지
output_files = sorted([f for f in os.listdir(output_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("output_files : ", output_files)
mer_list = []
for i in range(len(output_files)):
    work_file = os.path.join(output_path, output_files[i])
    print(f"{work_file} 작업중...")
    df = pd.read_excel(work_file)

    # 신규 그룹 컬럼 생성
    df["NEW"] = df["DATACOLLECTIONMEASUREMENT"] % 1000

    # 기존 DATACOLLECTIONMEASUREMENT 컬럼의 값이 같은 것끼리 평균 계산
    df_grouped = df.groupby("DATACOLLECTIONMEASUREMENT").mean()

    # VEHS(ALL) 컬럼의 값만 합 연산, 나머지는 평균
    df_newGrouped = df_grouped.groupby("NEW").agg(lambda x: x.sum() if x.name == "VEHS(ALL)" or x.name == "QUEUEDELAY(ALL)" else x.mean()).reset_index()

    df_newGrouped["VEHS(ALL)"] = df_newGrouped["VEHS(ALL)"] * 60
    df = df_newGrouped[["NEW", "VEHS(ALL)", "QUEUEDELAY(ALL)"]]
    del df_newGrouped

    # 진입부
    start_df = df[(df["NEW"] >= 1) & (df["NEW"] <=20)]
    # 본선부
    mid_df = df[(df["NEW"] >= 21) & (df["NEW"] <=100)]
    # 진출부
    end_df = df[(df["NEW"] >= 101) & (df["NEW"] <=120)]
    # 전체
    total_df = df[(df["NEW"] >= 1) & (df["NEW"] <=120)]

    # 평균 계산 전 "NEW" 제거
    df1 = start_df.drop(columns=["NEW"]).mean().to_frame().T
    df2 = mid_df.drop(columns=["NEW"]).mean().to_frame().T
    df3 = end_df.drop(columns=["NEW"]).mean().to_frame().T
    df4 = total_df.drop(columns=["NEW"]).mean().to_frame().T

    # 다차원 배열을 1차원 배열로 변환 -> 인덱싱 유리
    df1_vals = df1.values.flatten()
    df2_vals = df2.values.flatten()
    df3_vals = df3.values.flatten()
    df4_vals = df4.values.flatten()

    # 컬럼 정의
    columns = [
        "파일명",
        "VEHS(ALL)_진입", "VEHS(ALL)_본선", "VEHS(ALL)_진출", "VEHS(ALL)_전체",
        "QUEUEDELAY(ALL)_진입", "QUEUEDELAY(ALL)_본선", "QUEUEDELAY(ALL)_진출", "QUEUEDELAY(ALL)_전체"
    ]
    # 컬럼 순서 정렬
    merged_data = [
        output_files[i],
        df1_vals[0], df2_vals[0], df3_vals[0], df4_vals[0],  # VEHS(ALL)_*
        df1_vals[1], df2_vals[1], df3_vals[1], df4_vals[1],  # QUEUEDELAY(ALL)_*
    ]

    merged_df = pd.DataFrame([merged_data], columns=columns)
    mer_list.append(merged_df)


final_df = pd.concat(mer_list, ignore_index=True).round(4)

excel_path = os.path.join(output_path, "volume_output")
print("excel_path : ", excel_path)
if not os.path.exists(excel_path):
    os.makedirs(excel_path)
excel_file_path = os.path.join(excel_path, "volume_output.xlsx")
final_df.to_excel(excel_file_path, index=False)
print("작업이 완료 되었습니다.")
# Out:
# output_files :  ['1_output.xlsx', '2_output.xlsx', '3_output.xlsx', '4_output.xlsx', '5_output.xlsx', '6_output.xlsx', '7_output.xlsx', '8_output.xlsx', '9_output.xlsx', '10_output.xlsx', '11_output.xlsx', '12_output.xlsx', '13_output.xlsx', '14_output.xlsx', '15_output.xlsx', '16_output.xlsx', '17_output.xlsx', '18_output.xlsx', '19_output.xlsx', '20_output.xlsx', '21_output.xlsx', '22_output.xlsx', '23_output.xlsx', '24_output.xlsx']
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\1_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\2_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\3_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\4_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\5_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\6_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\7_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\8_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\9_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\10_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\11_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\12_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\13_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\14_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\15_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\16_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\17_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\18_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\19_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\20_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\21_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\22_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\23_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\24_output.xlsx 작업중...
# excel_path :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리_250409\결과파일\1350\volume_output
# 작업이 완료 되었습니다.
