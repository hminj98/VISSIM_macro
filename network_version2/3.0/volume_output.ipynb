# %%
"""output(결과) 파일에서 데이터 가공 (교통량, 지체시간)"""

import pandas as pd
import os
"""output 파일 양식 수정"""
output_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600" # 결과엑셀 파일이 있는 폴더경로까지
output_files = sorted([f for f in os.listdir(output_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]))
print("output_files : ", output_files)
mer_list = []
for i in range(len(output_files)):
    work_file = os.path.join(output_path, output_files[i])
    print(f"{work_file} 작업중...")
    df = pd.read_excel(work_file)

    # 신규 그룹 컬럼 생성
    df["NEW"] = df["DATACOLLECTIONMEASUREMENT"] % 1000

    # 기존 DATACOLLECTIONMEASUREMENT 컬럼의 값이 같은 것끼리 평균 계산
    df_grouped = df.groupby("DATACOLLECTIONMEASUREMENT").mean()

    # VEHS(ALL), QUEUEDELAY(ALL) 컬럼의 값만 합 연산, 나머지는 평균
    df_newGrouped = df_grouped.groupby("NEW").agg(lambda x: x.sum() if x.name == "VEHS(ALL)" or x.name == "QUEUEDELAY(ALL)" else x.mean()).reset_index()

    df_newGrouped["VEHS(ALL)"] = df_newGrouped["VEHS(ALL)"] * 60
    df = df_newGrouped[["NEW", "VEHS(ALL)", "QUEUEDELAY(ALL)"]]
    del df_newGrouped

    # 진입부
    start_df = df[(df["NEW"] >= 1) & (df["NEW"] <=20)]
    # 본선부
    mid_df = df[(df["NEW"] >= 21) & (df["NEW"] <=100)]
    # 진출부
    end_df = df[(df["NEW"] >= 101) & (df["NEW"] <=120)]
    # 전체
    total_df = df[(df["NEW"] >= 1) & (df["NEW"] <=120)]

    # 평균 계산 전 "NEW" 제거
    df1 = start_df.drop(columns=["NEW"]).sum().to_frame().T
    df2 = mid_df.drop(columns=["NEW"]).sum().to_frame().T
    df3 = end_df.drop(columns=["NEW"]).sum().to_frame().T
    df4 = total_df.drop(columns=["NEW"]).sum().to_frame().T

    # 다차원 배열을 1차원 배열로 변환 -> 인덱싱 유리
    df1_vals = df1.values.flatten()
    df2_vals = df2.values.flatten()
    df3_vals = df3.values.flatten()
    df4_vals = df4.values.flatten()

    # 컬럼 정의
    columns = [
        "파일명",
        "VEHS(ALL)_진입", "VEHS(ALL)_본선", "VEHS(ALL)_진출", "VEHS(ALL)_전체",
        "QUEUEDELAY(ALL)_진입", "QUEUEDELAY(ALL)_본선", "QUEUEDELAY(ALL)_진출", "QUEUEDELAY(ALL)_전체"
    ]
    # 컬럼 순서 정렬
    merged_data = [
        output_files[i],
        df1_vals[0], df2_vals[0], df3_vals[0], df4_vals[0],  # VEHS(ALL)_*
        df1_vals[1], df2_vals[1], df3_vals[1], df4_vals[1],  # QUEUEDELAY(ALL)_*
    ]

    merged_df = pd.DataFrame([merged_data], columns=columns)
    mer_list.append(merged_df)


final_df = pd.concat(mer_list, ignore_index=True).round(4)
display(final_df)

excel_path = os.path.join(output_path, "volume_output")
print("excel_path : ", excel_path)

if not os.path.exists(excel_path):
    os.makedirs(excel_path)
excel_file_path = os.path.join(excel_path, "volume_output.xlsx")
final_df.to_excel(excel_file_path, index=False)
print("작업이 완료 되었습니다.")
# Out:
# output_files :  ['1_output.xlsx', '2_output.xlsx', '3_output.xlsx', '4_output.xlsx', '5_output.xlsx', '6_output.xlsx', '7_output.xlsx', '8_output.xlsx', '9_output.xlsx', '10_output.xlsx', '11_output.xlsx', '12_output.xlsx', '13_output.xlsx', '14_output.xlsx', '15_output.xlsx', '16_output.xlsx', '17_output.xlsx', '18_output.xlsx', '19_output.xlsx', '20_output.xlsx', '21_output.xlsx', '22_output.xlsx', '23_output.xlsx', '24_output.xlsx', '25_output.xlsx', '26_output.xlsx', '27_output.xlsx', '28_output.xlsx', '29_output.xlsx', '30_output.xlsx', '31_output.xlsx', '32_output.xlsx', '33_output.xlsx', '34_output.xlsx', '35_output.xlsx', '36_output.xlsx', '37_output.xlsx', '38_output.xlsx', '39_output.xlsx', '40_output.xlsx', '41_output.xlsx', '42_output.xlsx', '43_output.xlsx', '44_output.xlsx', '45_output.xlsx', '46_output.xlsx', '47_output.xlsx', '48_output.xlsx', '49_output.xlsx', '50_output.xlsx', '51_output.xlsx', '52_output.xlsx', '53_output.xlsx', '54_output.xlsx', '55_output.xlsx', '56_output.xlsx', '57_output.xlsx', '58_output.xlsx', '59_output.xlsx', '60_output.xlsx', '61_output.xlsx', '62_output.xlsx', '63_output.xlsx', '64_output.xlsx', '65_output.xlsx', '66_output.xlsx', '67_output.xlsx', '68_output.xlsx', '69_output.xlsx', '70_output.xlsx', '71_output.xlsx', '72_output.xlsx']
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\1_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\2_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\3_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\4_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\5_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\6_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\7_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\8_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\9_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\10_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\11_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\12_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\13_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\14_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\15_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\16_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\17_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\18_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\19_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\20_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\21_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\22_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\23_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\24_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\25_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\26_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\27_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\28_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\29_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\30_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\31_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\32_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\33_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\34_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\35_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\36_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\37_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\38_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\39_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\40_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\41_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\42_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\43_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\44_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\45_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\46_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\47_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\48_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\49_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\50_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\51_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\52_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\53_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\54_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\55_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\56_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\57_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\58_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\59_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\60_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\61_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\62_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\63_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\64_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\65_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\66_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\67_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\68_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\69_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\70_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\71_output.xlsx 작업중...
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\72_output.xlsx 작업중...
#                파일명  VEHS(ALL)_진입  VEHS(ALL)_본선  VEHS(ALL)_진출  VEHS(ALL)_전체  \
# 0    1_output.xlsx       23821.4       95066.0       22551.1      141438.5
# 1    2_output.xlsx       23821.4       95066.1       22552.8      141440.3
# 2    3_output.xlsx       23821.4       95065.9       22557.8      141445.1
# 3    4_output.xlsx       23821.4       95066.0       22559.1      141446.5
# 4    5_output.xlsx       23659.5       94350.7       22368.9      140379.1
# ..             ...           ...           ...           ...           ...
# 67  68_output.xlsx       68129.1      271530.1       62837.1      402496.3
# 68  69_output.xlsx       67649.9      269705.5       63703.7      401059.1
# 69  70_output.xlsx       67643.5      269766.7       63780.3      401190.5
# 70  71_output.xlsx       67642.1      269748.3       63673.9      401064.3
# 71  72_output.xlsx       67640.8      269718.9       62711.9      400071.6
#
#     QUEUEDELAY(ALL)_진입  QUEUEDELAY(ALL)_본선  QUEUEDELAY(ALL)_진출  \
# 0                  0.0              0.0000              0.0000
# 1                  0.0              0.0000              0.0000
# 2                  0.0              0.0000              0.0000
# 3                  0.0              0.0000              0.0000
# 4                  0.0              0.0000              0.0000
# ..                 ...                 ...                 ...
# 67                 0.0              0.0132           1087.4733
# 68                 0.0              0.0853              1.8083
# 69                 0.0              0.0313              6.2988
# 70                 0.0              0.0213             57.0943
# 71                 0.0              0.0957            967.6678
#
#     QUEUEDELAY(ALL)_전체
# 0               0.0000
# 1               0.0000
# 2               0.0000
# 3               0.0000
# 4               0.0000
# ..                 ...
# 67           1087.4865
# 68              1.8937
# 69              6.3302
# 70             57.1157
# 71            967.7635
#
# [72 rows x 9 columns]
# excel_path :  C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\초장대 K-지하고속도로 인프라 안전 및 효율 향상 기술 개발(2차년도)\자료정리(2차로)_250411\시뮬레이션 분석 자료_V2.5\중차량,종단경사,교통량\결과파일\600\volume_output
# 작업이 완료 되었습니다.
