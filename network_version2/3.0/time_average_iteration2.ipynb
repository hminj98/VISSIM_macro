# %%
import shutil
import os
import pandas as pd
""".mer 파일에서 데이터 가공 (시간 구간 별 평균)"""
# 파일 경로 (Windows 경로를 올바르게 처리)
folder_path = r"C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1"

interval_value = 60
from_time = 1800
# 시뮬레이션 횟수
siml_count = 10
mer_count = 0
mer_name = "network02_mer" # 수정

destination_dir = os.path.join(folder_path, mer_name) # 파일명_mer 수정해야함
os.makedirs(destination_dir, exist_ok=True)  # 이미 존재하면 생성하지 않음
print("mer 폴더 생성")

mer_list = []
# .mer 파일 복사
for file in os.listdir(folder_path):
    if file.endswith(".mer"):  # .mer 확장자 필터링
        mer_list.append(file)
        source_path = os.path.join(folder_path, file)
        destination_path = os.path.join(destination_dir, file)
        shutil.copy2(source_path, destination_path)  # 파일 복사
print("총 .mer 파일 수 : ", len(mer_list))


for start in range(0, len(mer_list), siml_count):
    batch_files = mer_list[start:start+siml_count]
    df_list = []
    for file in batch_files:
        mer_path = os.path.join(destination_dir, file)
        print("mer_path : ", mer_path)
        # 파일 읽기
        with open(mer_path, "r", encoding="utf-8", errors="ignore") as file:
            lines = file.readlines()
        # 데이터가 시작하는 인덱스 찾기
        data_start_idx = None

        for j, line in enumerate(lines):
            if "Measurem." in line:  # 컬럼명이 포함된 행 찾기
                data_start_idx = j
                break

        # 데이터프레임 생성
        if data_start_idx is not None:
            # 컬럼명 추출
            columns = lines[data_start_idx].strip().split(";")

            # 데이터 부분 추출 및 가공
            data_lines = lines[data_start_idx + 1:]  # 컬럼명 제외, 데이터 부분
            data = [line.strip().split(";") for line in data_lines if line.strip()]

            # 데이터프레임 생성
            df = pd.DataFrame(data, columns=columns)
            # 컬럼명을 정리 (혹시 모를 공백 제거)
            df.columns = df.columns.str.strip()

            # 변환할 숫자형 컬럼 리스트
            numeric_columns = ["Measurem.", "t(Entry)", "t(Exit)", "VehNo", "Vehicle type",
                               "Line", "v[km/h]", "b[m/s2]", "Occ", "Pers", "tQueue", "VehLength[m]"]

            # 각 컬럼을 숫자로 변환
            for col in numeric_columns:
                if col in df.columns:  # 컬럼이 존재하는지 확인
                    df[col] = pd.to_numeric(df[col], errors="coerce")  # 변환 실패 시 NaN 처리
            df["time"] = df[["t(Entry)", "t(Exit)"]].max(axis=1)
            # 시간대별 범위 적용
            current_time = from_time
            max_time = df["time"].max()

            while current_time <= max_time:
                next_time = current_time + interval_value
                df.loc[df["time"].between(current_time, next_time, inclusive="right"), "time"] = next_time
                df.loc[df["time"] == 1800, "time"] = 1860
                current_time = next_time

            df = df.groupby(["time", "Measurem."])[["b[m/s2]", "Occ", "tQueue", "VehLength[m]", "v[km/h]"]].agg("mean").reset_index().round(2)
            df["time"] = df["time"].astype(int)
            df_list.append(df)
    merged_df = pd.concat(df_list, ignore_index=True)
    # 같은 time, Measurem. 기준으로 평균
    avg_df = merged_df.groupby(["time", "Measurem."])[["b[m/s2]", "Occ", "tQueue", "VehLength[m]", "v[km/h]"]].mean().reset_index().round(2)

    merout_path =os.path.join(destination_dir,"time_output")
    os.makedirs(merout_path, exist_ok=True)  # 이미 존재하면 생성하지 않음

    last_file = xlsx_files = sorted([f for f in os.listdir(merout_path) if f.endswith(".xlsx")], key=lambda x: int(x.split("_")[0]) if x.split("_")[0].isdigit() else 0)

    if not xlsx_files:
        last_file = 1
    else:
        last_file = int(xlsx_files[-1].split("_")[0])+1
    excel_path = os.path.join(merout_path,f"{last_file}_time_output.xlsx")
    avg_df.to_excel(excel_path, index=False)
    print("생성파일 : ", excel_path)
    mer_count += 1

    if mer_count >= len(mer_list)/siml_count:
        print("시뮬레이션 분석이 완료되었습니다.")
        break
# Out:
# mer 폴더 생성
# 총 .mer 파일 수 :  120
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_001.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_002.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_003.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_004.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_005.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_006.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_007.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_008.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_009.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_010.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\1_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_011.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_012.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_013.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_014.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_015.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_016.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_017.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_018.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_019.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_020.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\2_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_021.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_022.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_023.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_024.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_025.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_026.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_027.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_028.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_029.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_030.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\3_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_031.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_032.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_033.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_034.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_035.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_036.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_037.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_038.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_039.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_040.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\4_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_041.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_042.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_043.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_044.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_045.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_046.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_047.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_048.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_049.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_050.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\5_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_051.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_052.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_053.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_054.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_055.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_056.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_057.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_058.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_059.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_060.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\6_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_061.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_062.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_063.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_064.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_065.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_066.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_067.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_068.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_069.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_070.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\7_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_071.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_072.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_073.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_074.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_075.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_076.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_077.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_078.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_079.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_080.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\8_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_081.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_082.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_083.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_084.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_085.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_086.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_087.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_088.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_089.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_090.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\9_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_091.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_092.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_093.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_094.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_095.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_096.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_097.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_098.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_099.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_100.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\10_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_101.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_102.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_103.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_104.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_105.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_106.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_107.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_108.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_109.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_110.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\11_time_output.xlsx
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_111.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_112.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_113.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_114.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_115.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_116.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_117.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_118.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_119.mer
# mer_path :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\network02_수정_120.mer
# 생성파일 :  C:\VISSIM_Workspace\network_new\network_version2\network_version2.4.1\network03_mer\time_output\12_time_output.xlsx
# 시뮬레이션 분석이 완료되었습니다.
