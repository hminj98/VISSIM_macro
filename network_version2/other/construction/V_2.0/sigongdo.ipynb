# %%
import json
from collections import defaultdict
import pandas as pd
import os


""" 시공도 작성 """

folder_path = r"C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일"
save_path = os.path.join(folder_path, "pivot")
os.makedirs(save_path, exist_ok=True)
json_path = r"C:\Workspace\vissimTest_Python\network_version2\resource\route_name.json"

csv_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".csv")], key=lambda x: int(x.split("_")[0]) if x.split("_")[0].isdigit() else 0)

# 노선명 json 파일 읽어옴
with open(json_path, "r", encoding="utf-8") as f:
    route_name = json.load(f)

result_list = []
for file_name in csv_files:
    print(file_name + "작업중")
    df = pd.read_csv(os.path.join(folder_path, file_name), encoding="euc-kr")

    df['vds'] = df['vds'].astype(str).str.zfill(4)
    result = df.groupby(["vds_id", "point", "hour", "vds"]).mean().reset_index()
    result_list.append(result)
final_df = pd.concat(result_list, ignore_index=True)
final_df = final_df.groupby(["vds_id", "point", "hour", "vds"]).mean().reset_index()

final_df["type"] = final_df["vds_id"].str.extract(r'\d{4}(VD.)')

# vds, vde 구분 및 그룹화
vds_type_groups = {v: df for v, df in final_df.groupby(["vds", "type"])}

# 딕셔너리 자동 생성
vds_grouped = defaultdict(dict)

# 2차원 배열이 아니라, vds_val이라는 딕셔너리 안에 type_val 이라는 딕셔너리를 추가하는 것!
"""
vds_grouped = {
    '0010' : {
        'VDE' : df1
    }
}
"""
for (vds_val, type_val), df in vds_type_groups.items():
    vds_grouped[vds_val][type_val] = df

for vds_val, type_dict in vds_grouped.items():

    route = route_name.get(vds_val, "UnknownRoute")

    excel_file = os.path.join(save_path, f"{route}.xlsx")

    with pd.ExcelWriter(excel_file, engine="openpyxl") as writer:

        for type_val, df in type_dict.items():

            pivot_df = df.pivot_table(
                index="point",
                columns="hour",
                values="avgspeed",
                aggfunc="mean"
            )

            pivot_df.to_excel(writer, sheet_name=f"{type_val}")

    print(f"{excel_file} 저장 완료!")
print("=== 모든 파일 저장 완료 ===")
# Out:
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201102.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201103.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201104.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201105.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201106.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201109.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201110.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201111.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201112.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201113.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201116.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201117.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201123.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201124.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201125.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201126.csv작업중
# TB_COL_EX_T_SMHS_VDS_BROFIFO_15MIN_20201127.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211101.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211102.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211103.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211104.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211105.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211108.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211109.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211110.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211111.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211112.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211115.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211116.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211117.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211118.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211119.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211122.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211123.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211124.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20211125.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221101.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221102.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221103.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221104.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221107.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221108.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221109.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221110.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221111.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221114.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221115.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221116.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221117.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221118.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221121.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221122.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221123.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221124.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221125.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20221128.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231101.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231102.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231103.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231106.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231107.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231108.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231109.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231110.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231113.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231114.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231115.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231116.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231117.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231120.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231121.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231122.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231123.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231124.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231127.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20231128.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241101.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241104.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241105.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241106.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241107.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241108.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241111.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241112.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241113.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241114.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241115.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241118.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241119.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241120.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241121.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241122.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241125.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241126.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241127.csv작업중
# TR021900070005-EX_MIN15_VDS_RTP_TPSTS_TB-20241128.csv작업중
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\경부선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\남해선(순천-부산).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\남해선(영암-순천).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\부산신항선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\광주대구선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\무안광주선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\고창담양선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\함양울산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\서해안선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\평택시흥선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\울산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\평택화성선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\오산화성선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\서울문산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\서울문산지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\대구포항선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\익산장수선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\호남선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\논산천안선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\순천완주선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\구리포천선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\청주영덕선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\당진대전선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\옥산오창선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\당진청주선(아산-천안).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\통영대전선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\중부선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\제2중부선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\평택제천선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\중부내륙선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\영동선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\광주원주선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\중앙선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\대구부산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\서울양양선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\동해선(삼척-속초).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\부산울산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\동해선(부산-포항).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\대구외곽순환선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\수도권제1순환선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\남해1지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\남해2지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\제2경인선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\인천대교선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\인천대교지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\경인선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\신월여의지하도로.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\인천공항선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\서천공주선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\용인서울선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\호남지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\대전남부선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\상주영천선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\봉담동탄선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\인천김포선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\구리포천지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\봉담송산선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\화성광주선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\수도권제2순환선(화도-양평).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\수도권제2순환선(포천-화도).xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\중부내륙지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\광주외곽순환선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\중앙선지선.xlsx 저장 완료!
# C:\Users\(주)내일이엔시 도로교통안전연구소\Desktop\급경사\시공도\vds 데이터\이상치 제거\20~24년\11월\평일\pivot\부산외곽선.xlsx 저장 완료!
# === 모든 파일 저장 완료 ===
