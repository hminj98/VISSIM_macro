# %%
import shutil
import os
import pandas as pd


# 파일 경로 (Windows 경로를 올바르게 처리)
folder_path = r"C:\VISSIM_Workspace\network_new\network_final"

interval_value = 60
from_time = 1800

destination_dir = os.path.join(folder_path, "network01_mer") # 파일명_mer 수정해야함
os.makedirs(destination_dir, exist_ok=True)  # 이미 존재하면 생성하지 않음
mer_count = 0
mer_list = []
# .mer 파일 복사
for file in os.listdir(folder_path):
    if file.endswith(".mer"):  # .mer 확장자 필터링
        mer_count += 1
        mer_list.append(file)
        source_path = os.path.join(folder_path, file)
        destination_path = os.path.join(destination_dir, file)
        shutil.copy2(source_path, destination_path)  # 파일 복사
print("mer_list : ", mer_list)


for i in range(mer_count):
    mer_path = os.path.join(destination_dir, mer_list[i])
    print("mer_path : ", mer_path)
    # 파일 읽기
    with open(mer_path, "r", encoding="utf-8", errors="ignore") as file:
        lines = file.readlines()
    # 데이터가 시작하는 인덱스 찾기
    data_start_idx = None

    for j, line in enumerate(lines):
        if "Measurem." in line:  # 컬럼명이 포함된 행 찾기
            data_start_idx = j
            break

    # 데이터프레임 생성
    if data_start_idx is not None:
        # 컬럼명 추출
        columns = lines[data_start_idx].strip().split(";")

        # 데이터 부분 추출 및 가공
        data_lines = lines[data_start_idx + 1:]  # 컬럼명 제외, 데이터 부분
        data = [line.strip().split(";") for line in data_lines if line.strip()]

        # 데이터프레임 생성
        df = pd.DataFrame(data, columns=columns)
        # 컬럼명을 정리 (혹시 모를 공백 제거)
        df.columns = df.columns.str.strip()

        # 변환할 숫자형 컬럼 리스트
        numeric_columns = ["Measurem.", "t(Entry)", "t(Exit)", "VehNo", "Vehicle type",
                           "Line", "v[km/h]", "b[m/s2]", "Occ", "Pers", "tQueue", "VehLength[m]"]

        # 각 컬럼을 숫자로 변환
        for col in numeric_columns:
            if col in df.columns:  # 컬럼이 존재하는지 확인
                df[col] = pd.to_numeric(df[col], errors="coerce")  # 변환 실패 시 NaN 처리
        df["time"] = df[["t(Entry)", "t(Exit)"]].max(axis=1)
        # 시간대별 범위 적용
        current_time = from_time
        max_time = df["time"].max()

        while current_time <= max_time:
            next_time = current_time + interval_value
            df.loc[df["time"].between(current_time, next_time, inclusive="right"), "time"] = next_time
            df.loc[df["time"] == 1800, "time"] = 1860
            current_time = next_time

        df = df.groupby(["time", "Measurem."])[["b[m/s2]", "Occ", "tQueue", "VehLength[m]", "v[km/h]"]].agg("mean").reset_index().round(2)
        df["time"] = df["time"].astype(int)
        print(df)

        merout_path =os.path.join(destination_dir,"mer_output")
        os.makedirs(merout_path, exist_ok=True)  # 이미 존재하면 생성하지 않음
        excel_path = os.path.join(merout_path,mer_list[i]+".xlsx")
        df.to_excel(excel_path, index=False)
# Out:
# mer_list :  ['network01_001.mer', 'network01_002.mer', 'network01_003.mer', 'network01_004.mer', 'network01_005.mer', 'network01_006.mer', 'network01_007.mer', 'network01_008.mer', 'network01_009.mer', 'network01_010.mer', 'network01_011.mer', 'network01_012.mer']
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_001.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.59  0.04    0.00          5.13    60.88
# 1     1860          2    -0.67  0.05    0.00          5.50    63.02
# 2     1860          3    -0.17  0.05    0.89          5.27    45.14
# 3     1860          4    -0.39  0.05    0.43          5.68    48.06
# 4     1860          5     0.62  0.05    0.26          5.28    51.62
# ...    ...        ...      ...   ...     ...           ...      ...
# 7173  5400        118     0.00  0.05  123.78          5.07    88.14
# 7174  5400        119     0.07  0.04  124.19          5.85    92.43
# 7175  5400        120     0.08  0.05  123.28          5.10    93.16
# 7176  5400        121     0.07  0.05  123.74          5.89    96.08
# 7177  5400        122     0.12  0.05  123.66          5.18    94.29
#
# [7178 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_002.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.74  0.05    0.00          4.94    68.61
# 1     1860          2    -0.63  0.05    0.00          5.30    59.28
# 2     1860          3    -0.60  0.05    0.00          4.81    51.66
# 3     1860          4    -0.03  0.05    0.00          5.41    52.46
# 4     1860          5     0.05  0.05    0.00          4.86    48.39
# ...    ...        ...      ...   ...     ...           ...      ...
# 7124  5400        118    -0.19  0.05   18.30          5.23    53.72
# 7125  5400        119    -0.03  0.05   21.38          5.28    63.52
# 7126  5400        120     0.31  0.05   21.65          5.40    58.45
# 7127  5400        121     0.03  0.05   24.26          4.77    68.63
# 7128  5400        122     0.16  0.05   23.49          5.64    63.92
#
# [7129 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_003.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.59  0.05    0.00          5.47    54.32
# 1     1860          2    -0.52  0.05    0.00          5.38    53.55
# 2     1860          3    -0.03  0.05    2.43          5.40    43.36
# 3     1860          4     0.05  0.05    1.91          5.38    41.52
# 4     1860          5     0.61  0.05    1.71          5.35    50.58
# ...    ...        ...      ...   ...     ...           ...      ...
# 7133  5400        118     0.01  0.05  267.91          4.43    73.32
# 7134  5400        119    -0.40  0.05  262.74          4.47    82.48
# 7135  5400        120    -0.03  0.05  269.23          4.42    73.76
# 7136  5400        121    -0.40  0.04  265.91          4.44    72.62
# 7137  5400        122     0.01  0.05  270.10          4.47    73.46
#
# [7138 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_004.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.56  0.05    0.00          5.34    54.69
# 1     1860          2    -0.51  0.05    0.00          5.88    53.88
# 2     1860          3     0.20  0.06    1.32          5.55    42.53
# 3     1860          4     0.52  0.05    2.56          6.44    41.88
# 4     1860          5     0.74  0.05    1.39          5.56    51.69
# ...    ...        ...      ...   ...     ...           ...      ...
# 7079  5400        118     0.14  0.05  579.76          4.52    53.43
# 7080  5400        119     0.11  0.05  558.43          5.03    71.09
# 7081  5400        120     0.21  0.05  582.31          4.52    58.64
# 7082  5400        121     0.13  0.05  558.36          5.07    72.62
# 7083  5400        122     0.19  0.05  581.52          4.48    63.41
#
# [7084 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_005.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.58  0.05    0.00          5.27    55.55
# 1     1860          2    -0.55  0.05    0.00          5.73    54.60
# 2     1860          3     0.05  0.05    1.85          5.31    43.38
# 3     1860          4     0.27  0.06    2.88          5.46    42.02
# 4     1860          5     0.68  0.05    1.73          5.30    51.81
# ...    ...        ...      ...   ...     ...           ...      ...
# 7138  5400        118    -0.06  0.05  229.77          5.18    82.41
# 7139  5400        119    -0.14  0.05  231.96          4.94    83.64
# 7140  5400        120    -0.11  0.05  229.70          5.19    81.44
# 7141  5400        121    -0.09  0.04  232.29          5.08    82.31
# 7142  5400        122    -0.23  0.05  229.00          4.98    78.90
#
# [7143 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_006.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -1.26  0.06    0.00          5.02    33.50
# 1     1860          2    -0.61  0.05    0.00          5.34    41.46
# 2     1860          3     0.75  0.04    0.12          5.05    36.57
# 3     1860          4     0.84  0.05    2.28          5.66    48.78
# 4     1860          5     0.66  0.05    0.11          5.34    49.26
# ...    ...        ...      ...   ...     ...           ...      ...
# 7097  5400        118    -0.02  0.06  279.15          5.54    77.94
# 7098  5400        119    -0.02  0.05  279.93          6.33    81.23
# 7099  5400        120    -0.03  0.05  278.99          5.47    77.74
# 7100  5400        121    -0.01  0.06  279.94          6.28    81.15
# 7101  5400        122    -0.06  0.05  279.92          5.62    78.14
#
# [7102 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_007.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.51  0.04    0.00          5.55    49.57
# 1     1860          2    -0.62  0.04    0.00          4.62    49.67
# 2     1860          3     0.58  0.05    2.78          5.32    42.19
# 3     1860          4     0.45  0.05    1.97          4.58    40.83
# 4     1860          5     0.89  0.05    2.35          5.21    58.72
# ...    ...        ...      ...   ...     ...           ...      ...
# 7169  5400        118    -0.05  0.05  121.13          6.15    62.98
# 7170  5400        119     0.05  0.05  119.30          5.40    77.36
# 7171  5400        120     0.09  0.05  118.30          6.38    61.21
# 7172  5400        121     0.27  0.05  118.13          4.93    79.06
# 7173  5400        122     0.00  0.05  113.55          6.43    59.32
#
# [7174 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_008.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.90  0.05    0.00          5.54    66.36
# 1     1860          2    -0.70  0.05    0.00          5.34    50.22
# 2     1860          3    -0.50  0.05    0.00          5.59    56.55
# 3     1860          4     0.29  0.05    0.00          5.31    36.63
# 4     1860          5    -0.03  0.05    0.00          5.32    53.77
# ...    ...        ...      ...   ...     ...           ...      ...
# 7082  5400        118     0.02  0.05  404.64          5.11    70.02
# 7083  5400        119     0.06  0.04  392.56          6.26    60.97
# 7084  5400        120     0.16  0.05  406.71          5.22    66.98
# 7085  5400        121     0.12  0.05  393.88          5.86    63.96
# 7086  5400        122     0.22  0.05  402.88          5.19    67.23
#
# [7087 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_009.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.53  0.05    0.00          5.74    65.30
# 1     1860          2    -0.48  0.05    0.00          5.09    61.02
# 2     1860          3    -0.39  0.06    0.78          5.86    48.05
# 3     1860          4    -0.24  0.05    0.65          4.96    47.51
# 4     1860          5     0.40  0.05    0.92          6.00    50.22
# ...    ...        ...      ...   ...     ...           ...      ...
# 7194  5400        118    -0.06  0.06   45.34          6.15    81.09
# 7195  5400        119     0.21  0.06   43.48          5.70    80.71
# 7196  5400        120     0.03  0.05   45.13          6.08    80.90
# 7197  5400        121    -0.00  0.06   42.63          6.21    82.36
# 7198  5400        122     0.09  0.05   45.12          6.32    82.11
#
# [7199 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_010.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.55  0.05    0.00          5.62    58.76
# 1     1860          2    -0.51  0.05    0.00          5.57    59.57
# 2     1860          3    -0.21  0.05    0.99          5.40    44.76
# 3     1860          4    -0.19  0.05    0.84          5.80    47.49
# 4     1860          5     0.88  0.05    1.83          5.48    54.65
# ...    ...        ...      ...   ...     ...           ...      ...
# 7122  5400        118     0.05  0.05   56.91          5.57    70.91
# 7123  5400        119    -0.06  0.05   52.51          5.60    72.25
# 7124  5400        120     0.09  0.05   56.66          5.35    72.63
# 7125  5400        121     0.01  0.05   50.37          5.44    73.78
# 7126  5400        122     0.07  0.04   55.93          5.58    73.10
#
# [7127 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_011.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.54  0.05    0.00          6.24    57.98
# 1     1860          2    -0.53  0.05    0.00          5.61    58.14
# 2     1860          3    -0.16  0.05    0.95          6.30    42.73
# 3     1860          4    -0.25  0.05    0.83          5.85    43.89
# 4     1860          5     0.95  0.05    1.60          6.12    53.37
# ...    ...        ...      ...   ...     ...           ...      ...
# 7068  5400        118    -0.05  0.06  215.04          5.64    61.51
# 7069  5400        119    -0.02  0.05  221.93          5.48    68.96
# 7070  5400        120     0.01  0.05  215.17          5.62    60.78
# 7071  5400        121    -0.06  0.05  220.36          5.43    67.69
# 7072  5400        122     0.13  0.05  213.83          5.75    61.85
#
# [7073 rows x 7 columns]
# mer_path :  C:\VISSIM_Workspace\network_new\network_final\network01_mer\network01_012.mer
#       time  Measurem.  b[m/s2]   Occ  tQueue  VehLength[m]  v[km/h]
# 0     1860          1    -0.57  0.05    0.00          5.35    62.80
# 1     1860          2    -0.67  0.06    0.00          5.74    62.34
# 2     1860          3    -0.38  0.05    1.77          5.13    44.04
# 3     1860          4    -0.24  0.05    0.11          5.63    46.35
# 4     1860          5     0.60  0.05    1.39          5.26    48.61
# ...    ...        ...      ...   ...     ...           ...      ...
# 7051  5400        118    -0.04  0.05  488.61          7.06    62.16
# 7052  5400        119    -0.03  0.05  494.28          5.94    60.99
# 7053  5400        120    -0.03  0.06  486.55          6.62    60.04
# 7054  5400        121    -0.01  0.05  493.48          5.91    58.24
# 7055  5400        122    -0.05  0.06  491.10          6.11    58.20
#
# [7056 rows x 7 columns]
